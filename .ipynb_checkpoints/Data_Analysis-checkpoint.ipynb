# %% [markdown]
# # Preprocessing

# %% [markdown]
# ### Resources:
# 1. [collocation](https://www.youtube.com/watch?v=Kf25kCKuOUI)
# 2. [Unicode and WHy?](https://www.youtube.com/watch?v=sqPTR_v4qFA)
# 3. [concordance](http://www.nltk.org/book/ch01.html)
# 4. [vader sentiment analysis](http://www.nltk.org/howto/sentiment.html)

# %%
#The following commands import the modules, algorithms, corpora, lists that will be needed for exploratory book analysis
import nltk #imports the nltk module
nltk.download("words") # downloads English words
nltk.download("stopwords") # downloads English stopwords 
from nltk.text import Text #imports the Text module that enables the exploratory search of the text
from nltk import bigrams # imports the bigrams module
from nltk.collocations import * # imports the collocations methods
import string # imports string module that allows running processs on strings
from string import punctuation # imports punctuation symbols
import os #this module allows interfacing with the underlying operating system
import re #imports regular expression module 
from collections import OrderedDict #imports collections module, an alternative to list, dict, set, tuple
from nltk.draw import dispersion_plot
from IPython.display import display # a module that wraps the object to be displayed
# Out:
# [nltk_data] Downloading package words to /home/harish/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/harish/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import pandas as pd
import os
# from wordcloud import WordCloud
import matplotlib.pyplot as plt
# %matplotlib inline

os.chdir('/home/harish/PycharmProjects/NewsOptimism/')
df = pd.read_csv('csvdataset/11192017/cnn.csv')
df = df.dropna(how='any')

# %%
df.shape
df['TITLE'].iloc[326]
# Out:
# 'The naked truth'

# %%
df['SUMMARY'].iloc[326]
# Out:
# 'To her 5,000 friends and thousands more followers on Facebook, Paulette was already a hero.\n"I lost my mother to breast cancer but I know if she were alive, she would be walking with you -- the whole way.\nIt was God who woke her up one night in December 2013 to tell her she had breast cancer, which doctors later confirmed.\nShe worried a lump under her arm was the return of breast cancer, and supporters overwhelmed her with more prayers.\nAnnette Johnson, a longtime acquaintance of PauletteAnd then there was this: She told Paulette she was marrying her long-lost love.'

# %%
maxdf = {}
max_i = 0
for i in range(df.shape[0]):
    maxdf[i] = len(str(df['TEXT'].iloc[i]))
print(sorted(maxdf.items(), key=lambda x:x[1], reverse=True))
# Out:
# [(326, 69924), (250, 68707), (112, 50964), (106, 38367), (823, 36668), (361, 36488), (897, 34847), (32, 33119), (571, 32342), (284, 30725), (555, 27119), (253, 26917), (44, 26700), (438, 26242), (327, 25790), (201, 25194), (689, 24906), (905, 24906), (640, 24840), (424, 24163), (311, 23719), (518, 23241), (759, 22106), (425, 22071), (3, 20602), (737, 20197), (319, 20004), (672, 18657), (683, 18505), (524, 18468), (437, 18387), (835, 18264), (410, 18165), (499, 17766), (53, 17702), (369, 17693), (647, 17693), (287, 17255), (659, 16666), (341, 16076), (72, 15876), (183, 15855), (894, 15630), (73, 15622), (472, 15622), (473, 15610), (731, 15610), (212, 15351), (373, 15351), (564, 15334), (301, 15251), (14, 15243), (487, 15047), (6, 15035), (732, 15035), (343, 14923), (521, 14923), (851, 14918), (47, 14865), (39, 14676), (460, 14476), (216, 14236), (734, 14067), (720, 13895), (295, 13877), (703, 13877), (501, 13837), (671, 13719), (276, 13711), (769, 13711), (929, 13460), (919, 13092), (696, 12967), (181, 12801), (590, 12732), (771, 12732), (704, 12701), (49, 12600), (370, 12500), (895, 12376), (147, 12319), (903, 12253), (397, 12249), (923, 12136), (215, 12056), (24, 12005), (865, 11979), (291, 11880), (799, 11880), (218, 11740), (207, 11676), (842, 11658), (255, 11520), (76, 11423), (91, 11419), (881, 11377), (281, 11337), (100, 11181), (600, 11181), (639, 11165), (537, 11027), (336, 10963), (592, 10963), (767, 10960), (420, 10893), (320, 10839), (239, 10834), (667, 10814), (908, 10630), (755, 10577), (509, 10521), (717, 10423), (80, 10305), (543, 10287), (440, 10263), (516, 10263), (675, 10211), (11, 10048), (580, 9993), (788, 9859), (423, 9822), (477, 9822), (753, 9723), (900, 9720), (838, 9694), (358, 9676), (486, 9659), (545, 9613), (209, 9602), (860, 9524), (646, 9509), (422, 9471), (917, 9455), (809, 9445), (845, 9316), (229, 9177), (567, 9133), (763, 9085), (807, 9077), (208, 9074), (711, 8899), (550, 8839), (633, 8824), (153, 8797), (372, 8689), (495, 8687), (416, 8658), (290, 8574), (722, 8574), (86, 8523), (435, 8461), (610, 8461), (607, 8366), (93, 8282), (240, 8221), (249, 8181), (493, 8181), (401, 8179), (904, 8179), (22, 8177), (454, 8177), (236, 8162), (94, 8159), (166, 8138), (30, 8134), (191, 8130), (15, 8104), (79, 8092), (294, 8076), (230, 8051), (852, 8045), (304, 8024), (730, 8009), (264, 7958), (576, 7956), (9, 7925), (46, 7925), (833, 7895), (906, 7895), (88, 7891), (913, 7891), (313, 7826), (332, 7823), (297, 7722), (219, 7695), (762, 7695), (663, 7659), (33, 7654), (136, 7654), (698, 7610), (907, 7610), (335, 7605), (67, 7581), (826, 7581), (25, 7550), (155, 7526), (834, 7505), (884, 7479), (277, 7453), (588, 7453), (480, 7452), (161, 7361), (628, 7345), (562, 7320), (636, 7295), (735, 7295), (597, 7291), (805, 7291), (231, 7254), (356, 7252), (623, 7239), (890, 7195), (572, 7192), (241, 7167), (856, 7119), (237, 7117), (824, 7117), (604, 7089), (710, 7083), (328, 7031), (814, 7022), (695, 7012), (781, 7011), (386, 7010), (892, 7000), (476, 6997), (697, 6997), (488, 6996), (482, 6978), (797, 6978), (366, 6975), (551, 6960), (468, 6942), (298, 6908), (400, 6890), (534, 6872), (462, 6862), (829, 6862), (174, 6850), (503, 6839), (653, 6822), (804, 6817), (146, 6777), (75, 6758), (508, 6747), (429, 6739), (606, 6736), (352, 6727), (439, 6726), (741, 6726), (52, 6722), (349, 6718), (586, 6697), (665, 6697), (34, 6667), (505, 6647), (365, 6630), (99, 6614), (58, 6607), (382, 6607), (226, 6588), (159, 6585), (292, 6582), (873, 6576), (89, 6570), (456, 6517), (594, 6504), (293, 6464), (444, 6463), (234, 6460), (853, 6454), (199, 6440), (285, 6399), (643, 6377), (874, 6317), (179, 6314), (699, 6314), (375, 6303), (924, 6303), (848, 6281), (839, 6253), (525, 6218), (307, 6205), (685, 6205), (546, 6189), (158, 6180), (887, 6180), (587, 6176), (662, 6176), (622, 6168), (203, 6152), (625, 6136), (466, 6131), (584, 6131), (858, 6096), (452, 6094), (795, 6081), (512, 6076), (649, 6076), (60, 6071), (50, 6068), (220, 60 ...

# %%
#Testing with single text:
data = str(df['TEXT'][326])
data = data.replace("\n","")

# %%
import string

# %%
words_string = nltk.word_tokenize(data)
words_string#need to remove punctuations# todo
len(words_string)
# Out:
# 13989

# %% [markdown]
# ## Removing stop words:

# %%
custom_stopwords = ['said','say']

# %%
stopwords = set(nltk.corpus.stopwords.words("english"))
# len(stopwords)

for w in custom_stopwords:
    stopwords.add(w)
# if 'says' in stopwords:
#     print("true")

# %%
#To remove single character's punctations(char len 2) and stopwords; also lower words:
words_string = [word.lower() for word in words_string if (len(word) > 2 and word.lower() not in stopwords)]
# reduced list:
len(words_string)
# Out:
# 6201

# %%
#converting back to text
textList = Text(words_string)
textList[:]
# Out:
# ['cnn',
#  'behind',
#  'double-mastectomy',
#  'scars',
#  'run',
#  'across',
#  'bare',
#  'chest',
#  'story',
#  'tell.so',
#  'late',
#  'last',
#  'april',
#  'paulette',
#  'leaphart',
#  'embarked',
#  '1,000-mile',
#  'walk',
#  'childhood',
#  'hometown',
#  'biloxi',
#  'mississippi',
#  'halls',
#  'congress',
#  'washington.and',
#  'topless.the',
#  'breast',
#  'cancer',
#  'survivor',
#  'screamed',
#  'cure',
#  'demanded',
#  'better',
#  'affordable',
#  'health',
#  'care',
#  'wanted',
#  'women',
#  'without',
#  'breasts',
#  'believe',
#  'beauty',
#  'proud',
#  'strength',
#  'showcasing',
#  'embracing',
#  'scars',
#  'hoped',
#  'inspire',
#  'others',
#  'same.her',
#  'journey',
#  'bold',
#  'visual',
#  'moving',
#  'offered',
#  'hero',
#  'admire',
#  'given',
#  'paulette',
#  'audacious',
#  'decision',
#  'walk',
#  'shirtless',
#  'face',
#  'strangers',
#  'rich',
#  'spectacle',
#  'witness',
#  'spoke',
#  'african-american',
#  'women',
#  'face',
#  'highest',
#  'breast',
#  'cancer',
#  'mortality',
#  'rate',
#  'inspired',
#  'legions',
#  'survivors',
#  'spoke',
#  'many',
#  'lost',
#  'someone',
#  'disease.it',
#  'seemed',
#  'storyteller',
#  'dream',
#  'reality',
#  'would',
#  'eventually',
#  'intrude.documentary',
#  'filmmakers',
#  'first',
#  'seize',
#  'paulette',
#  'potential',
#  'approached',
#  'producer',
#  'shoot',
#  'lifted',
#  'shirt',
#  'said',
#  'story',
#  'needed',
#  'told',
#  'stunning',
#  'trailer',
#  'scar',
#  'story',
#  'film',
#  'crew',
#  'would',
#  'follow',
#  'entire',
#  'walk',
#  'released',
#  'late',
#  'october',
#  '2015.a',
#  'kickstarter',
#  'campaign',
#  'help',
#  'fund',
#  'film',
#  'went',
#  'weeks',
#  'walk',
#  'began',
#  'attracting',
#  'enthusiastic',
#  'donors',
#  'journalists',
#  'flocked',
#  'paulette',
#  'eager',
#  'tell',
#  'story',
#  'even',
#  'megastar',
#  'beyoncé',
#  'took',
#  'notice',
#  'featured',
#  'paulette',
#  'lemonade',
#  'saw',
#  'trailer',
#  'facebook',
#  'like',
#  'many',
#  'others',
#  'hooked',
#  'world',
#  'hungry',
#  'heroes',
#  'whose',
#  'stories',
#  'inspiration',
#  'bring',
#  'light',
#  'amid',
#  'darkness',
#  'paulette',
#  'seemed',
#  'feed',
#  'craving',
#  'making',
#  'calls',
#  'learning',
#  'walking',
#  '8-year-old',
#  'daughter',
#  'less',
#  'hopped',
#  'car',
#  'picked',
#  'amateur',
#  'photographer',
#  'stepson',
#  'headed',
#  'north',
#  'carolina',
#  'walk',
#  'her.some',
#  'stories',
#  'land',
#  'journalist',
#  'plate',
#  'like',
#  'manna',
#  'heaven',
#  "'re",
#  'perfect',
#  'morsels',
#  "n't",
#  'wait',
#  'share',
#  'others',
#  'arrive',
#  'mess',
#  'ingredients',
#  'recipe',
#  'follow',
#  'one',
#  'started',
#  'first',
#  'way',
#  'finished',
#  'other.after',
#  'walking',
#  'paulette',
#  'full',
#  'day',
#  'left',
#  'questions',
#  'answers',
#  'matter',
#  'much',
#  'hated',
#  'admit',
#  'aspects',
#  'story',
#  'simply',
#  "n't",
#  'add',
#  'kept',
#  'digging',
#  'inconsistencies',
#  'found',
#  'past',
#  'cancer',
#  'treatment',
#  'much',
#  'actually',
#  'walking',
#  'even',
#  'motivations.part',
#  'wanted',
#  'walk',
#  'away',
#  'paulette',
#  'story',
#  'even',
#  'one',
#  'woman',
#  'life',
#  'saved',
#  'thanks',
#  'conversation',
#  'paulette',
#  'started',
#  "n't",
#  'enough',
#  'hero',
#  'flawed',
#  'thought',
#  'thousands',
#  'people',
#  'following',
#  'paulette',
#  'facebook',
#  'journalists',
#  'covered',
#  'journey',
#  'online',
#  'video',
#  'viewed',
#  'million',
#  'times.and',
#  'realized',
#  'story',
#  "n't",
#  'paulette',
#  'need',
#  'find',
#  'become',
#  'heroes',
#  'unchecked',
#  'storytelling',
#  'self-promotion',
#  'thrives',
#  'social',
#  'media',
#  'disappointment',
#  'feel',
#  'reality',
#  'jolts',
#  'awake',
#  'reverie.in',
#  'desperation',
#  'believe',
#  'people',
#  'dole',
#  'passes',
#  'easily',
#  'collective',
#  'enchantment',
#  'paulette',
#  'become',
#  'blind',
#  'shameka',
#  'fulston',
#  'left',
#  'others',
#  'join',
#  'paulette',
#  'leaphart',
#  'community',
#  'walk',
#  'charlotte',
#  'fulston',
#  'planned',
#  'rejoin',
#  'paulette',
#  'last',
#  '100',
#  'miles',
#  'walk',
#  'left',
#  'charlotte',
#  'feeling',
#  'disenchanted.a',
#  'vision',
#  'godi',
#  'caught',
#  'paulette',
#  'house',
#  'outside',
#  'charlotte',
#  'north',
#  'carolina',
#  'daughter',
#  'staying',
#  'grill',
#  'fired',
#  'food',
#  'filled',
#  'counters',
#  'music',
#  'pumping',
#  'paulette',
#  'wore',
#  't-shirt',
#  'emblazoned',
#  'words',
#  'living',
#  'beautifully',
#  'greeted',
#  'hug',
#  'walk',
#  'given',
#  'back',
#  'everything',
#  'devil',
#  'stole',
#  'told',
#  'room',
#  'gathered',
#  'pray',
#  'journey.the',
#  'hostess',
#  'said',
#  'opened',
#  'home',
#  'lost',
#  'sister',
#  'breast',
#  'cancer',
#  'tears',
#  'fell',
#  'told',
#  'paulette',
#  'wanted',
#  'take',
#  'care',
#  'dusk',
#  'turned',
#  'night',
#  'kept',
#  'eye',
#  'time',
#  'spoke',
#  'phone',
#  'paulette',
#  'warned',
#  'woke',
#  '4:30',
#  'morning',
#  'walked',
#  'miles',
#  'day',
#  'except',
#  'weekends',
#  'rest',
#  'cover',
#  'sort',
#  'ground',
#  'explained',
#  'wanted',
#  'meet',
#  'goal',
#  'reaching',
#  'washington',
#  'june',
#  '50th',
#  'birthday',
#  'decent',
#  'shape',
#  'walking',
#  'least',
#  'miles',
#  'little',
#  'sleep',
#  'scared',
#  "'re",
#  'starting',
#  "'til",
#  'a.m.',
#  'tomorrow',
#  'paulette',
#  'finally',
#  'told',
#  'night',
#  'wore',
#  'community',
#  'walk',
#  'planned',
#  'downtown',
#  'charlotte',
#  'breathed',
#  'sigh',
#  'relief.the',
#  'next',
#  'morning',
#  'crowd',
#  'passionate',
#  'small',
#  'three',
#  'dozen',
#  'women',
#  'men',
#  'children',
#  'many',
#  'wore',
#  'pink',
#  'touched',
#  'breast',
#  'cancer',
#  'five',
#  'years',
#  'october',
#  'said',
#  'one',
#  'woman',
#  'nine',
#  'years',
#  'cancer-free',
#  'said',
#  'another',
#  'sporting',
#  'fight',
#  'like',
#  'girl',
#  't-shirt',
#  'mom',
#  'died',
#  '2004',
#  'said',
#  'one',
#  'man',
#  'survived',
#  'lymphoma',
#  'himself.a',
#  'woman',
#  'driven',
#  'night',
#  'took',
#  'shirt',
#  'reveal',
#  'tangled',
#  'scars',
#  'seen',
#  'paulette',
#  'atlanta',
#  'vowed',
#  'walk',
#  'her.after',
#  'photos',
#  'videos',
#  'prayers',
#  'walkers',
#  'hit',
#  'pavement',
#  'weaving',
#  'way',
#  'downtown',
#  'need',
#  'cure',
#  'need',
#  'cure',
#  'screamed',
#  'following',
#  'paulette',
#  'lead',
#  'breast',
#  'cancer',
#  'sucks',
#  'breast',
#  'cancer',
#  'sucks',
#  'also',
#  'sang',
#  'hymns',
#  'walk',
#  'defeat',
#  'demon',
#  'paulette',
#  'yelled.all',
#  'pain',
#  'felt',
#  'day',
#  'born',
#  'purpose',
#  'living',
#  'purpose',
#  'god',
#  'said',
#  'going',
#  'use',
#  'chest',
#  'paulette',
#  'leaphartit',
#  'memorial',
#  'day',
#  'one',
#  'month',
#  'day',
#  'since',
#  'started',
#  'streets',
#  'quiet',
#  'occasional',
#  'onlookers',
#  'gawked',
#  'wondering',
#  'commotion',
#  'walked',
#  'along',
#  'taking',
#  'notes',
#  'wondered',
#  'effective',
#  'small',
#  '1-mile',
#  'march',
#  'really',
#  'interested',
#  'would',
#  'come',
#  'next',
#  'walk',
#  'resuming',
#  'daughter',
#  'reach',
#  'washington',
#  'less',
#  'month.they',
#  'already',
#  'covered',
#  '710',
#  'miles',
#  'walked',
#  '100',
#  'paulette',
#  'said',
#  'said',
#  'often',
#  'used',
#  'cabs',
#  'carry',
#  'dangerous',
#  'parts',
#  'journey',
#  'weekends',
#  'would',
#  'mean',
#  'averaged',
#  'miles',
#  'day',
#  'foot.we',
#  'got',
#  'started',
#  'around',
#  'noon',
#  'pictured',
#  'rambling',
#  'rolling',
#  'hills',
#  'green',
#  'paulette',
#  'would',
#  'like',
#  'forrest',
#  'gump',
#  'thought',
#  'gathering',
#  'disciples',
#  'strode',
#  'quaint',
#  'towns.paulette',
#  'preferred',
#  'busier',
#  'route',
#  'steered',
#  'toward',
#  'mind',
#  'safer',
#  'along',
#  'highways',
#  'could',
#  'message',
#  'seen',
#  'carried',
#  'sign',
#  'insisting',
#  'scars',
#  'told',
#  'story.to',
#  '5,000',
#  'friends',
#  'thousands',
#  'followers',
#  'facebook',
#  'paulette',
#  'already',
#  'hero',
#  'showered',
#  'love',
#  'praise',
#  '10,000',
#  'thousand',
#  'tongues',
#  'could',
#  "n't",
#  'thank',
#  'enough',
#  'one',
#  'person',
#  'wrote',
#  'day',
#  'walked',
#  'understand',
#  'fight',
#  'god',
#  'every',
#  'step',
#  'way',
#  'love',
#  'wrote',
#  'another',
#  'brave',
#  'woman',
#  'year',
#  'phenomenal',
#  'woman',
#  'wrote',
#  'third',
#  'lost',
#  'mother',
#  'breast',
#  'cancer',
#  'know',
#  'alive',
#  'would',
#  'walking',
#  'whole',
#  'way',
#  '...',
#  'god',
#  'bless',
#  'paulette',
#  'inspired',
#  'women',
#  'world',
#  'said',
#  'even',
#  'saved',
#  'lives',
#  'people',
#  'considering',
#  'suicide',
#  'said',
#  'motivated',
#  'on.the',
#  'global',
#  'attention',
#  'began',
#  'two',
#  'years',
#  'earlier',
#  'labor',
#  'day',
#  'weekend',
#  'posted',
#  'topless',
#  'photos',
#  'beach',
#  'mississippi',
#  'emerged',
#  'eight',
#  'months',
#  'depression',
#  'losing',
#  'breasts',
#  'told',
#  'could',
#  "n't",
#  'reconstructive',
#  'surgery',
#  'pre-existing',
#  'blood-clotting',
#  'disorder',
#  'vision',
#  'god',
#  'biloxi',
#  'beach',
#  'take',
#  'shirt',
#  'photographed.she',
#  'said',
#  'people',
#  'surrounded',
#  'woman',
#  'began',
#  'cry',
#  'onlookers',
#  'applauded',
#  'paulette',
#  'freed',
#  'moment',
#  'posting',
#  'photos',
#  'facebook',
#  'others',
#  'said',
#  'man',
#  'wrote',
#  'thank',
#  'saying',
#  'wife',
#  'lost',
#  'breasts',
#  'years',
#  'finally',
#  'bared',
#  'chest',
#  'him.she',
#  'chosen',
#  'god',
#  'vessel',
#  'work',
#  'said',
#  'photos',
#  'liked',
#  'almost',
#  '300,000',
#  'times',
#  'god',
#  'woke',
#  'one',
#  'night',
#  'december',
#  '2013',
#  'tell',
#  'breast',
#  'cancer',
#  'doctors',
#  'later',
#  'confirmed',
#  'god',
#  'told',
#  '1,000-mile',
#  'topless',
#  'walk',
#  'pain',
#  'felt',
#  'day',
#  'born',
#  'purpose',
#  'living',
#  'purpose',
#  'said',
#  'god',
#  'said',
#  'going',
#  'use',
#  'chest',
#  'pushing',
#  'daughter',
#  'weighed-down',
#  'stroller',
#  'paulette',
#  'leaphart',
#  'winds',
#  'way',
#  'downtown',
#  'charlotte',
#  'continue',
#  'journey',
#  'toward',
#  'washington.the',
#  'first',
#  'signsbased',
#  'expressions',
#  'people',
#  'passed',
#  'everyone',
#  'saw',
#  'purpose',
#  'joked',
#  'must',
#  'look',
#  'like',
#  'bag',
#  'lady',
#  'others',
#  'got',
#  'offered',
#  'cheers',
#  'hugs',
#  'church',
#  'group',
#  'giving',
#  'toiletries',
#  'homeless',
#  'people',
#  'gathered',
#  'circle',
#  'prayers',
#  'two',
#  'women',
#  'bikes',
#  'seen',
#  'story',
#  'rode',
#  'passed',
#  'bills.paulette',
#  'said',
#  'ate',
#  'fruit',
#  'walked',
#  'day',
#  'though',
#  'ate',
#  'fried',
#  'chicken',
#  'tenders',
#  'popeyes',
#  'two',
#  'hot',
#  'dogs',
#  'cook',
#  'southern',
#  'fast-food',
#  'chain',
#  "n't",
#  'judging',
#  'choices',
#  'matched',
#  'everything',
#  'ate',
#  "n't",
#  'eat',
#  'apple',
#  'offered',
#  'never',
#  'saw',
#  'eat',
#  'piece',
#  'fruit.it',
#  'one',
#  'tiny',
#  'perhaps',
#  'silly',
#  'observations',
#  'filed',
#  'away',
#  "n't",
#  'guilty',
#  'saying',
#  'different',
#  'things',
#  'especially',
#  'comes',
#  'diet',
#  'heat',
#  'slowed',
#  'said',
#  'aiming',
#  'miles',
#  'day',
#  'news',
#  'came',
#  'relief',
#  'late',
#  'afternoon',
#  'though',
#  "n't",
#  'even',
#  'gone',
#  'miles',
#  'sometimes',
#  'daughter',
#  'trudged',
#  'along',
#  'often',
#  'climbed',
#  'stroller',
#  'built',
#  'kids',
#  'less',
#  'half',
#  'size',
#  'bags',
#  'spilled',
#  'sides',
#  'one',
#  'balanced',
#  'across',
#  'lap',
#  'several',
#  'times',
#  'awkward',
#  'contraption',
#  'tumbled',
#  'getting',
#  'out.while',
#  'picking',
#  'scattered',
#  'belongings',
#  'overstuffed',
#  'wallet',
#  'sunscreen',
#  'bug',
#  'spray',
#  'water',
#  'bottles',
#  'daughter',
#  'jesus',
#  'storybook',
#  'bible',
#  'paulette',
#  'told',
#  'already',
#  'lost',
#  'driver',
#  'license',
#  'passport',
#  'check',
#  'hotels',
#  'asked',
#  'knowing',
#  'desk',
#  'clerks',
#  'always',
#  'ask',
#  'everyone',
#  'knows',
#  'answered',
#  'smile',
#  'made',
#  'another',
#  'mental',
#  'note.the',
#  'highway',
#  'walked',
#  'along',
#  'grew',
#  'busy',
#  'paulette',
#  'daughter',
#  'stroller',
#  'often',
#  'caught',
#  'holding',
#  'breath',
#  'cars',
#  'whizzed',
#  'by.in',
#  'hottest',
#  'part',
#  'day',
#  'took',
#  'breaks',
#  'sometimes',
#  'said',
#  'daughter',
#  'studied',
#  ...]

# %% [markdown]
# ### Finding some context:

# %%
textList.concordance('woman')
# Out:
# Displaying 25 of 28 matches:
# ed walk away paulette story even one woman life saved thanks conversation paule
# t cancer five years october said one woman nine years cancer-free said another
#  one man survived lymphoma himself.a woman driven night took shirt reveal tangl
# ry step way love wrote another brave woman year phenomenal woman wrote third lo
#  another brave woman year phenomenal woman wrote third lost mother breast cance
# tographed.she said people surrounded woman began cry onlookers applauded paulet
# internet ever put down.only one said woman n't know spreading lies criminal rec
#  know spreading lies criminal record woman suspected crazy jealous woman determ
# record woman suspected crazy jealous woman determined ignore.what documentary g
# ested god knows could leave homeless woman someone reached wondering could orga
# rly mccarty paulette chief adversary woman paulette said spreading lies her.pau
# east cancer deeply personal decision woman makes doctor.perhaps paulette radiat
#  facebook posts critical pauletteone woman get caught carmen lawrence cleveland
# ours side marveled calling strongest woman alive.local reporters popped meet fi
# cars something never done walked one woman chest discolored radiation burns alm
# ubled pretty sure oncologist surgeon woman lost one breasts cancer said later w
# n lost one breasts cancer said later woman devout catholic n't doubt power god
# canned crowd looking shameka fulston woman driven night atlanta walk paulette c
# ence ever existing labor day weekend woman consistently posted facebook multipl
# ople ask questions 've told time one woman noticing paulette posts newfound fam
# able touches one person inspires one woman get mammogram n't win activist added
# lette journey said saw facebook post woman stage paulette said successfully pra
# ant makeup artist.we need story need woman need woman tip tongues nikky finney
# artist.we need story need woman need woman tip tongues nikky finney poet author
# ulette shero stopped tracks reminded woman truly made iron lavender need story

# %%
textList.similar('said')
# textList._word_context_index.similar_words('woman')
# Out:
# implants zane

# %%
#builds a text index object: based on the textlist
textIndex = nltk.text.ContextIndex(textList)

# %%
#how simil
sorted(textIndex.word_similarity_dict('cancer').items(), key=lambda x:x[1], reverse=True)
# Out:
# [('cancer', 1.0),
#  ('african-american', 0.02631578947368421),
#  ('implants', 0.02631578947368421),
#  ('uber', 0),
#  ('fee', 0),
#  ('warned', 0),
#  ('indeed', 0),
#  ('radiation', 0),
#  ('watched', 0),
#  ('custody', 0),
#  ('ultrasound', 0),
#  ('shows', 0),
#  ('state', 0),
#  ('herded', 0),
#  ('way.she', 0),
#  ('live', 0),
#  ('mistakes.mccarty', 0),
#  ('video', 0),
#  ('additional', 0),
#  ('sympathetic', 0),
#  ('posh', 0),
#  ('gawked', 0),
#  ('brca', 0),
#  ('calling', 0),
#  ('digging', 0),
#  ('may', 0),
#  ('sank', 0),
#  ('direction', 0),
#  ('ones', 0),
#  ('lifestyle', 0),
#  ('remember', 0),
#  ("'ve", 0),
#  ('relieved', 0),
#  ('affordable', 0),
#  ('directly', 0),
#  ('disorder', 0),
#  ('relief.the', 0),
#  ('washington.the', 0),
#  ('conversations', 0),
#  ('ante', 0),
#  ('immediate', 0),
#  ('launch', 0),
#  ('train', 0),
#  ('publicly', 0),
#  ('qualify', 0),
#  ('visited', 0),
#  ('fight', 0),
#  ('thanked', 0),
#  ('power', 0),
#  ('diagnoses', 0),
#  ('years', 0),
#  ('access', 0),
#  ('recalled', 0),
#  ('wallet', 0),
#  ('intention', 0),
#  ('card', 0),
#  ('sidney', 0),
#  ('tearjerker', 0),
#  ('cyst.one', 0),
#  ('it.paulette', 0),
#  ('biloxi', 0),
#  ('kill', 0),
#  ('intrigued', 0),
#  ('hero', 0),
#  ('attributed', 0),
#  ('story', 0),
#  ('showered', 0),
#  ('bankruptcy', 0),
#  ('weekends', 0),
#  ('determined', 0),
#  ('whizzed', 0),
#  ('newfound', 0),
#  ('girl', 0),
#  ('license', 0),
#  ('catch', 0),
#  ('doctors', 0),
#  ('call', 0),
#  ('affecting', 0),
#  ('social', 0),
#  ('poked', 0),
#  ('stole', 0),
#  ('protect', 0),
#  ('rested', 0),
#  ('lithia', 0),
#  ('entire', 0),
#  ('battling', 0),
#  ('frequent', 0),
#  ('knack', 0),
#  ('legislative', 0),
#  ('nights', 0),
#  ('4.8', 0),
#  ('credit', 0),
#  ('amens', 0),
#  ('lives', 0),
#  ('premiere', 0),
#  ('words', 0),
#  ('thriving', 0),
#  ('santa', 0),
#  ('color', 0),
#  ('johnson.johnson', 0),
#  ('sure', 0),
#  ('carry', 0),
#  ('already', 0),
#  ('venture', 0),
#  ('orleans', 0),
#  ('tongues', 0),
#  ('over-the-top', 0),
#  ('finally', 0),
#  ('newfangled', 0),
#  ('pages', 0),
#  ('valued', 0),
#  ('beauty', 0),
#  ('difference', 0),
#  ('hormones', 0),
#  ('rep.', 0),
#  ('least', 0),
#  ('unfair', 0),
#  ('alive', 0),
#  ('suspected', 0),
#  ('garden', 0),
#  ('used', 0),
#  ('change', 0),
#  ('consent', 0),
#  ('show', 0),
#  ('zane', 0),
#  ('video.the', 0),
#  ('memorial', 0),
#  ('charging', 0),
#  ('request', 0),
#  ('convicted', 0),
#  ('photographer', 0),
#  ('demanded', 0),
#  ('diagnosis', 0),
#  ('pneumonia', 0),
#  ('sign', 0),
#  ('further.i', 0),
#  ('shop', 0),
#  ('distance', 0),
#  ('contraption', 0),
#  ('obligation', 0),
#  ('bag', 0),
#  ('plans', 0),
#  ('bakula.hollywood', 0),
#  ('alive.local', 0),
#  ('interpret', 0),
#  ('adversary', 0),
#  ('piece', 0),
#  ('married', 0),
#  ('exploitation', 0),
#  ('ride', 0),
#  ('eventually', 0),
#  ('mission', 0),
#  ('remembers', 0),
#  ('choices', 0),
#  ('washington', 0),
#  ('posted', 0),
#  ('seen', 0),
#  ('able', 0),
#  ('lavender', 0),
#  ('directionpart', 0),
#  ('choose', 0),
#  ('head', 0),
#  ('embracing', 0),
#  ('him.she', 0),
#  ('tear', 0),
#  ('cabs', 0),
#  ('since', 0),
#  ('noon', 0),
#  ('every', 0),
#  ('hair', 0),
#  ('interpreted', 0),
#  ('predated', 0),
#  ('lead', 0),
#  ('indicated', 0),
#  ('started', 0),
#  ('downtown', 0),
#  ('purpose', 0),
#  ('tumors', 0),
#  ('visits', 0),
#  ('beds', 0),
#  ('ncis', 0),
#  ('doctor', 0),
#  ('noted', 0),
#  ('bless', 0),
#  ('reporting', 0),
#  ('climbed', 0),
#  ('bare', 0),
#  ('facebookafter', 0),
#  ('responsible', 0),
#  ('screens', 0),
#  ('teamat', 0),
#  ('remains', 0),
#  ('november', 0),
#  ('sun', 0),
#  ('sleep', 0),
#  ('far-flung', 0),
#  ('notice', 0),
#  ('ever', 0),
#  ('believable', 0),
#  ('offered', 0),
#  ('fruit', 0),
#  ('summer', 0),
#  ('survivors', 0),
#  ('forrest', 0),
#  ('condition', 0),
#  ('preached', 0),
#  ('critics', 0),
#  ('story.blocked', 0),
#  ('media.her', 0),
#  ('totaling', 0),
#  ('votes', 0),
#  ('respond', 0),
#  ('keynote', 0),
#  ('observations', 0),
#  ('gone', 0),
#  ('weaving', 0),
#  ('different', 0),
#  ('vice', 0),
#  ('scott', 0),
#  ('class', 0),
#  ('long-lost', 0),
#  ('wept', 0),
#  ('passport', 0),
#  ('comes', 0),
#  ('approached', 0),
#  ('phone', 0),
#  ('side', 0),
#  ('disciples', 0),
#  ('widely', 0),
#  ('lease', 0),
#  ('2004', 0),
#  ('involved', 0),
#  ('2015.a', 0),
#  ('clear.the', 0),
#  ('irs.paulette', 0),
#  ('promised', 0),
#  ('christmas', 0),
#  ('including', 0),
#  ('outing', 0),
#  ('quaint', 0),
#  ('arrive', 0),
#  ('attacks', 0),
#  ('dedicate', 0),
#  ('heat', 0),
#  ('best', 0),
#  ('paths', 0),
#  ('retirement', 0),
#  ('pauletteone', 0),
#  ('hear', 0),
#  ('mississippi.paulette', 0),
#  ('fighting', 0),
#  ('sister', 0),
#  ('well.i', 0),
#  ('civil', 0),
#  ('capital', 0),
#  ('1,000', 0),
#  ('owed', 0),
#  ('maybe', 0),
#  ('cry', 0),
#  ('2013', 0),
#  ('houston', 0),
#  ('total', 0),
#  ('story.i', 0),
#  ('place', 0),
#  ('read', 0),
#  ('wallets', 0),
#  ('benign', 0),
#  ('accusations', 0),
#  ('intentions', 0),
#  ('died', 0),
#  ('bakula', 0),
#  ('active', 0),
#  ('owns', 0),
#  ('lawrence', 0),
#  ('smith', 0),
#  ('address', 0),
#  ('shirt', 0),
#  ('got', 0),
#  ('other.paulette', 0),
#  ('anymore', 0),
#  ('reports', 0),
#  ('thing', 0),
#  ('lymph', 0),
#  ('wedding', 0),
#  ('choice', 0),
#  ('carried', 0),
#  ('legal', 0),
#  ('keeping', 0),
#  ('cries', 0),
#  ('betrayed', 0),
#  ('hills', 0),
#  ('congratulate', 0),
#  ('gathered', 0),
#  ('hundreds.then', 0),
#  ('darkness', 0),
#  ('eager', 0),
#  ('history', 0),
#  ('mirror', 0),
#  ('obama', 0),
#  ('mccarty', 0),
#  ('seen.i', 0),
#  ('himself.a', 0),
#  ('considering', 0),
#  ('blisters', 0),
#  ('breathed', 0),
#  ('feel', 0),
#  ('booklets', 0),
#  ('along', 0),
#  ('angelina', 0),
#  ('alone', 0),
#  ('life', 0),
#  ('person', 0),
#  ('decent', 0),
#  ('meetings', 0),
#  ('captured', 0),
#  ('defaulted', 0),
#  ('sin', 0),
#  ('driver', 0),
#  ('barbara', 0),
#  ('temporarily', 0),
#  ('strength', 0),
#  ('took', 0),
#  ("'re", 0),
#  ('disorder.family', 0),
#  ('praying', 0),
#  ('eastern', 0),
#  ('miles.the', 0),
#  ('men', 0),
#  ('posts', 0),
#  ('criticism', 0),
#  ('potential', 0),
#  ('records', 0),
#  ('career', 0),
#  ('order', 0),
#  ('court', 0),
#  ('hated', 0),
#  ('self-reported', 0),
#  ('terms', 0),
#  ('worker', 0),
#  ('help.court', 0),
#  ('pathology', 0),
#  ('artist', 0),
#  ('cars', 0),
#  ('dental', 0),
#  ('word', 0),
#  ('passes', 0),
#  ('shero', 0),
#  ('four', 0),
#  ('flashing', 0),
#  ('insisted', 0),
#  ('ended', 0),
#  ('marveled', 0),
#  ('kept', 0),
#  ('promise', 0),
#  ('outrageous', 0),
#  ('time', 0),
#  ('conscience', 0),
#  ('hometown', 0),
#  ('saw', 0),
#  ('oncology', 0),
#  ('shared', 0),
#  ('lemons', 0),
#  ('logistics', 0),
#  ('bringing', 0),
#  ('spokeswoman', 0),
#  ('liked', 0),
#  ('lowest', 0),
#  ('grandkids', 0),
#  ('homeless.when', 0),
#  ('parts', 0),
#  ('tenders', 0),
#  ('homeless', 0),
#  ('eight', 0),
#  ('chance', 0),
#  ('walk', 0),
#  ('showcasing', 0),
#  ('rent', 0),
#  ('stroller', 0),
#  ('contradictions', 0),
#  ('hooked', 0),
#  ('envisioned', 0),
#  ('discrepancies', 0),
#  ('sit', 0),
#  ('certain', 0),
#  ('bottles', 0),
#  ('rooms', 0),
#  ('continue', 0),
#  ('fix', 0),
#  ('details', 0),
#  ('mom', 0),
#  ('candy', 0),
#  ('similarly', 0),
#  ('dr.', 0),
#  ('human', 0),
#  ('rates', 0),
#  ('walking', 0),
#  ('shrugged', 0),
#  ('globe.the', 0),
#  ('pick', 0),
#  ('young', 0),
#  ('mind', 0),
#  ('connections', 0),
#  ('people', 0),
#  ('identity', 0),
#  ('better', 0),
#  ('questionable', 0),
#  ('judgment', 0),
#  ('discuss', 0),
#  ('starting', 0),
#  ('six', 0),
#  ('confirmed', 0),
#  ('flocked', 0),
#  ('claiming', 0),
#  ('left', 0),
#  ('johnson', 0),
#  ('liable', 0),
#  ('said.other', 0),
#  ('travel', 0),
#  ('permission', 0),
#  ('carmen', 0),
#  ('mounted', 0),
#  ('represented.other', 0),
#  ('walkers', 0),
#  ('highways', 0),
#  ('star', 0),
#  ('influenced', 0),
#  ('quadruple', 0),
#  ('receive', 0),
#  ('preventionthe', 0),
#  ('weighed', 0),
#  ('overwhelmed', 0),
#  ('dangerous.fulston', 0),
#  ('dermatologist', 0),
#  ('wicker', 0),
#  ('safer', 0),
#  ('comment', 0),
#  ('really', 0),
#  ('author', 0),
#  ('spurts', 0),
#  ('take', 0),
#  ('choir', 0),
#  ('apple', 0),
#  ('event', 0),
#  ('file', 0),
#  ('notes', 0),
#  ('visual', 0),
#  ('outlets', 0),
#  ('dinner', 0),
#  ('giving', 0),
#  ('pauletteit', 0),
#  ('fax', 0),
#  ('noticing', 0),
#  ('ovary', 0),
#  ('shirts', 0),
#  ('worth', 0),
#  ('me.still', 0),
#  ('leisure', 0),
#  ('diet', 0),
#  ('honoring', 0),
#  ('shirtless', 0),
#  ('modeling', 0),
#  ('hyperpigmentation', 0),
#  ('gotten', 0),
#  ('activism', 0),
#  ('keep', 0),
#  ('loved', 0),
#  ('oblige', 0),
#  ('circle', 0),
#  ('balanced', 0),
#  ('prone', 0),
#  ('immediately', 0),
#  ('enthusiasm', 0),
#  ('bed', 0),
#  ('lies', 0),
#  ('another', 0),
#  ('southern', 0),
#  ('small', 0),
#  ('look', 0),
#  ('stomach', 0),
#  ('initially', 0),
#  ('brain', 0),
#  ('check', 0),
#  ('bible', 0),
#  ('learning', 0),
#  ('seasons', 0),
#  ('d-new', 0),
#  ('talk', 0),
#  ('planned', 0),
#  ('irs', 0),
#  ('sorry', 0),
#  ('clear', 0),
#  ('pass', 0),
#  ('photos', 0),
#  ('feet', 0),
#  ('interests', 0),
#  ('hundreds', 0),
#  ('month', 0),
#  ('ravaged', 0),
#  ('mounted.one', 0),
#  ('understood', 0),
#  ('rally', 0),
#  ('evidence', 0),
#  ('built', 0),
#  ('witness', 0),
#  ('hungry', 0),
#  ('overstuffed', 0),
#  ('north', 0),
#  ('discussing', 0),
#  ('picking', 0),
#  ('monitoring', 0),
#  ('covering', 0),
#  ('teens', 0),
#  ('comprehensive', 0),
#  ('breasts', 0),
#  ('certainly', 0),
#  ('racial', 0),
#  ('drove', 0),
#  ('first', 0),
#  ('workout', 0),
#  ('heroes.there', 0),
#  ('talks', 0),
#  ('disenchanted.a', 0),
#  ('way.soon', 0),
#  ('supporters', 0),
#  ('walked', 0),
#  ('hospital', 0),
#  ('embrace', 0),
#  ('trying', 0),
#  ('discolored', 0),
#  ('chicken', 0),
#  ('shows.i', 0),
#  ('heaven', 0),
#  ('chime', 0),
#  ('tabs', 0),
#  ('insisting', 0),
#  ('shameka', 0),
#  ('personalities', 0),
#  ('friends', 0),
#  ('prefer', 0),
#  ('payne', 0),
#  ('connick', 0),
#  ('hoped', 0),
#  ('pushed', 0),
#  ('leather', 0),
#  ('enlisted', 0),
#  ('shoot', 0),
#  ('april', 0),
#  ('lady', 0),
#  ('face', 0),
#  ('towns.paulette', 0),
#  ('200,000', 0),
#  ('feed', 0),
#  ('fiancé', 0),
#  ('expenses', 0),
#  ('counters', 0),
#  ('account', 0),
#  ('questions.outside', 0),
#  ('prayed', 0),
#  ('july', 0),
#  ('motivated', 0),
#  ('shaved', 0),
#  ('revolutionized', 0),
#  ('buy', 0),
#  ('david', 0),
#  ('hard', 0),
#  ('picked', 0),
#  ('site', 0),
#  ('resort', 0),
#  ('bug', 0),
#  ('languishing', 0),
#  ('song', 0),
#  ('appointments', 0),
#  ('collection', 0),
#  ('weird', 0),
#  ('sets', 0),
#  ('710', 0),
#  ('watching', 0),
#  ('judging', 0),
#  ('loose', 0),
#  ('reported.in', 0),
#  ('awarded', 0),
#  ('yellow', 0),
#  ('cook', 0),
#  ('bared', 0),
#  ('expenses.on', 0),
#  ('way', 0),
#  ('home', 0),
#  ('around', 0),
#  ('admire', 0),
#  ('truth', 0),
#  ('bolstering', 0),
#  ('dishonest', 0),
#  ('claus', 0),
#  ('spoke.several', 0),
#  ('reconstructive', 0),
#  ('city', 0),
#  ('journey.they', 0),
#  ('takes', 0),
#  ('nuts', 0),
#  ('cried', 0),
#  ('never', 0),
#  ('hug', 0),
#  ('hesitationbeyond', 0),
#  ('breath', 0),
#  ('sometimes', 0),
#  ('next', 0),
#  ('coy', 0),
#  ('pumping', 0),
#  ('scanned', 0),
#  ('red', 0),
#  ('israel.these', 0),
#  ('survive', 0),
#  ('reminded', 0),
#  ('beating', 0),
#  ('sick', 0),
#  ('signs', 0),
#  ('immediate.you', 0),
#  ('tips', 0),
#  ('anger', 0),
#  ('food', 0),
#  ('right', 0),
#  ('little', 0),
#  ('strangers', 0),
#  ('director', 0),
#  ('21st', 0),
#  ('date', 0),
#  ('away.they', 0),
#  ('remove', 0),
#  ('third', 0),
#  ('hesitant', 0),
#  ('lasted', 0),
#  ('streets', 0),
#  ('setting', 0),
#  ('snuff', 0),
#  ('assured', 0),
#  ('virginia', 0),
#  ('fruit.it', 0),
#  ('necessary.it', 0),
#  ('open', 0),
#  ('attention.black', 0),
#  ('100,000', 0),
#  ('margin', 0),
#  ('makes', 0),
#  ('fort', 0),
#  ('glamour', 0),
#  ('surprise', 0),
#  ('recording', 0),
#  ('brenda', 0),
#  ('still', 0),
#  ('end', 0),
#  ('become', 0),
#  ('best-selling', 0),
#  ('offer', 0),
#  ('it.they', 0),
#  ('brave', 0),
#  ('bouncing', 0),
#  ('6.3', 0),
#  ('interstate.i', 0),
#  ('advantage', 0),
#  ('doubts', 0),
#  ('greeted', 0),
#  ('session.she', 0),
#  ('featured', 0),
#  ('jones', 0),
#  ('knows', 0),
#  ('a.m.', 0),
#  ('legions', 0),
#  ('bold', 0),
#  ('emblazoned', 0),
#  ('godi', 0),
#  ('tiny', 0),
#  ('due', 0),
#  ('advised', 0),
#  ('speakers', 0),
#  ('reporters', 0),
#  ('pair', 0),
#  ('late', 0),
#  ('abused', 0),
#  ('more.her', 0),
#  ('explain', 0),
#  ('bizarre', 0),
#  ('looking', 0),
#  ('judgments', 0),
#  ('reaching', 0),
#  ('shape', 0),
#  ('reflected', 0),
#  ('real', 0),
#  ('feared', 0),
#  ('troubled', 0),
#  ('eyes', 0),
#  ('critic', 0),
#  ('chronicled', 0),
#  ('dole', 0),
#  ('white', 0),
#  ('forgotten', 0),
#  ('surmise', 0),
#  ('ethnic', 0),
#  ('death', 0),
#  ('seem', 0),
#  ('trusted', 0),
#  ('disability', 0),
#  ('respect', 0),
#  ('breast', 0),
#  ('documentary', 0),
#  ('rolled', 0),
#  ('financial', 0),
#  ('ask', 0),
#  ('...', 0),
#  ('ashia', 0),
#  ('pinkett', 0),
#  ('weight.whether', 0),
#  ('quit', 0),
#  ('ago', 0),
#  ('aged', 0),
#  ('mcdonald', 0),
#  ('beaumont', 0),
#  ('sexually', 0),
#  ('unravel.she', 0),
#  ('reservations', 0),
#  ('obesity', 0),
#  ('working', 0),
#  ('ongoing', 0),
#  ('shoes', 0),
#  ('waving', 0),
#  ('sounded', 0),
#  ('oncologist', 0),
#  ('chosen', 0),
#  ('rock', 0),
#  ('education', 0),
#  ('had.what', 0),
#  ('cause', 0),
#  ('diverged', 0),
#  ('schedule', 0),
#  ('needed', 0),
#  ('enough', 0),
#  ('online', 0),
#  ('cbs', 0),
#  ('celebrity', 0),
#  ('cast', 0),
#  ('mentioned', 0),
#  ('double', 0),
#  ('member', 0),
#  ('crossing', 0),
#  ('departure', 0),
#  ('drive', 0),
#  ('publisher', 0),
#  ('witch', 0),
#  ('skincare', 0),
#  ('father', 0),
#  ('1,000-mile', 0),
#  ('given', 0),
#  ('battled', 0),
#  ('fulston', 0),
#  ('occasional', 0),
#  ('parted', 0),
#  ('ways', 0),
#  ('appearing', 0),
#  ('give', 0),
#  ('erotic-fiction', 0),
#  ('relative', 0),
#  ('peek', 0),
#  ('effort', 0),
#  ('moment', 0),
#  ('facing', 0),
#  ('backi', 0),
#  ('hence', 0),
#  ('slowed', 0),
#  ('miles', 0),
#  ('unclear', 0),
#  ('filing', 0),
#  ('scrapped', 0),
#  ('posed', 0),
#  ('always', 0),
#  ('foster', 0),
#  ('argue', 0),
#  ('mental', 0),
#  ('shyamalan', 0),
#  ('attend', 0),
#  ('say.annette', 0),
#  ('marry', 0),
#  ('collective', 0),
#  ('street', 0),
#  ('see', 0),
#  ('arrangements', 0),
#  ('amateur', 0),
#  ('area', 0),
#  ('outlining', 0),
#  ('journey', 0),
#  ('bill', 0),
#  ('bikes', 0),
#  ('depleted', 0),
#  ('relationship', 0),
#  ('much', 0),
#  ('body', 0),
#  ('crew', 0),
#  ('re-excision', 0),
#  ('trimmed', 0),
#  ('two', 0),
#  ('recorded', 0),
#  ('bills.paulette', 0),
#  ('compromised', 0),
#  ('carefully', 0),
#  ('blowing', 0),
#  ('surgery', 0),
#  ('newspaper', 0),
#  ('roads', 0),
#  ('inflated', 0),
#  ('filmmakers', 0),
#  ('devil', 0),
#  ('control', 0),
#  ('abandoned', 0),
#  ('auto', 0),
#  ('wrote', 0),
#  ('chemotherapy', 0),
#  ('1.the', 0),
#  ('positive', 0),
#  ('last', 0),
#  ('admit', 0),
#  ('said.the', 0),
#  ('reach', 0),
#  ('gaynor', 0),
#  ('prepared', 0),
#  ('deal', 0),
#  ('screamed', 0),
#  ('gene', 0),
#  ('connected', 0),
#  ('man', 0),
#  ('lemonade', 0),
#  ('messageone', 0),
#  ('cover', 0),
#  ('business', 0),
#  ('thrives', 0),
#  ('seattle', 0),
#  ('birth', 0),
#  ('medical', 0),
#  ('laws', 0),
#  ('50th', 0),
#  ('wish', 0),
#  ('writes', 0),
#  ('tragic', 0),
#  ('crowd', 0),
#  ('new', 0),
#  ('zane.an', 0),
#  ('capitol', 0),
#  ('followers', 0),
#  ('wrote.other', 0),
#  ('like', 0),
#  ('craig', 0),
#  ('roof', 0),
#  ('stay-at-home', 0),
#  ('pretense', 0),
#  ('matched', 0),
#  ('clearly', 0),
#  ('owned', 0),
#  ('escalade.i', 0),
#  ('messenger.there', 0),
#  ('quiet', 0),
#  ('lump', 0),
#  ('surgical', 0),
#  ('taxi', 0),
#  ('requested', 0),
#  ('step', 0),
#  ('hottest', 0),
#  ('notoriety', 0),
#  ('done.an', 0),
#  ('partners', 0),
#  ('tomorrow', 0),
#  ('wore', 0),
#  ('authorat', 0),
#  ('seven', 0),
#  ('touch', 0),
#  ('happened', 0),
#  ('deserves', 0),
#  ('long', 0),
#  ('riding', 0),
#  ('downright', 0),
#  ('often', 0),
#  ('whole', 0),
#  ('moving', 0),
#  ('tumor', 0),
#  ('laugh', 0),
#  ('contacted', 0),
#  ('making', 0),
#  ('upworthy', 0),
#  ('questionsthe', 0),
#  ('pavement', 0),
#  ('relief', 0),
#  ('applauded', 0),
#  ('fly', 0),
#  ('unable', 0),
#  ('bags', 0),
#  ('on.the', 0),
#  ('stylist', 0),
#  ('donald', 0),
#  ('winfrey', 0),
#  ('documentary.the', 0),
#  ('kids', 0),
#  ('popped', 0),
#  ('throughout', 0),
#  ('outside', 0),
#  ('allowed', 0),
#  ('water', 0),
#  ('fan', 0),
#  ('45,000', 0),
#  ('remarks', 0),
#  ('blind', 0),
#  ('turn', 0),
#  ('sharing', 0),
#  ('document', 0),
#  ('sandwich', 0),
#  ('trusting', 0),
#  ('oprah', 0),
#  ('day', 0),
#  ('1-mile', 0),
#  ('mastectomy', 0),
#  ('lumpectomy', 0),
#  ('flood', 0),
#  ('hairstylist', 0),
#  ('trial', 0),
#  ('resuming', 0),
#  ('faced', 0),
#  ('catholic', 0),
#  ('mortality', 0),
#  ('recent', 0),
#  ('move', 0),
#  ('punked', 0),
#  ('big', 0),
#  ('storytelling', 0),
#  ('meeting', 0),
#  ('center', 0),
#  ('come', 0),
#  ('1,200', 0),
#  ('described', 0),
#  ('released', 0),
#  ('doubt', 0),
#  ('journalists', 0),
#  ('dogs', 0),
#  ('reading', 0),
#  ('cures', 0),
#  ('40,000', 0),
#  ('vaginal', 0),
#  ('mackenzie', 0),
#  ('cnn', 0),
#  ('scattered', 0),
#  ('reminding', 0),
#  ('bullied', 0),
#  ('editor', 0),
#  ('her.after', 0),
#  ('failed', 0),
#  ('treated', 0),
#  ('country.but', 0),
#  ('ignore.what', 0),
#  ('though', 0),
#  ('encouraged', 0),
#  ('summit', 0),
#  ('feeling', 0),
#  ('free', 0),
#  ('ailments', 0),
#  ('light', 0),
#  ('d.c.', 0),
#  ('girlfriends', 0),
#  ('setbacksbefore', 0),
#  ('surrounded', 0),
#  ('unfriended', 0),
#  ('think', 0),
#  ('hosted', 0),
#  ('scarred', 0),
#  ('characteristics', 0),
#  ('climb', 0),
#  ('maclin', 0),
#  ('frolicked', 0),
#  ('deathly', 0),
#  ('4:30', 0),
#  ('trailer', 0),
#  ('early', 0),
#  ('paying', 0),
#  ('capitoli', 0),
#  ('cut', 0),
#  ('tell.so', 0),
#  ('appeared', 0),
#  ('paulette.one', 0),
#  ('cleared', 0),
#  ('appearance', 0),
#  ('cases', 0),
#  ('mother-in-law', 0),
#  ('murkiest', 0),
#  ('edge', 0),
#  ('t-shirt', 0),
#  ('exercise', 0),
#  ('shaping', 0),
#  ('records.what', 0),
#  ('less', 0),
#  ('finished', 0),
#  ('continued', 0),
#  ('persuaded', 0),
#  ('aides', 0),
#  ('profit', 0),
#  ('discussed', 0),
#  ('population', 0),
#  ('share', 0),
#  ...]

# %%
textList.dispersion_plot(['man','woman', 'cancer', "story"])

# %% [markdown]
# ##### Freq Distribution

# %%
fdist = nltk.FreqDist(words_string)
for word, freq in fdist.most_common(100):
    display("%s %d" % (str(word), freq))
# Out:
# 'paulette 261'
# 'said 155'
# 'cancer 79'
# "n't 76"
# 'told 57'
# 'walk 50'
# 'story 47'
# 'day 45'
# 'could 44'
# 'one 40'
# 'breast 39'
# 'facebook 33'
# 'people 28'
# 'woman 28'
# 'would 28'
# 'women 26'
# 'daughter 26'
# 'asked 24'
# 'walked 21'
# 'made 21'
# 'leaphart 21'
# 'took 20'
# 'wanted 20'
# 'mccarty 19'
# 'like 19'
# 'way 19'
# 'god 18'
# 'care 18'
# 'others 18'
# 'left 17'
# 'first 17'
# 'help 17'
# 'miles 17'
# 'got 16'
# 'johnson 16'
# 'also 16'
# 'years 16'
# 'posted 15'
# 'saw 15'
# 'never 15'
# 'new 15'
# 'treatment 15'
# 'time 14'
# 'often 14'
# 'another 14'
# 'know 14'
# 'going 14'
# 'later 14'
# 'walking 13'
# 'began 13'
# 'felt 12'
# 'smith 12'
# 'along 12'
# 'home 12'
# 'cummings 12'
# 'even 12'
# 'get 12'
# 'knew 12'
# 'back 12'
# 'washington 11'
# 'take 11'
# 'next 11'
# 'money 11'
# 'filmmakers 11'
# 'lost 11'
# 'mother 11'
# 'saying 11'
# 'need 11'
# 'something 11'
# 'lawrence 10'
# "'re 10"
# 'shared 10'
# 'film 10'
# 'always 10'
# 'much 10'
# 'less 10'
# 'charlotte 10'
# 'want 10'
# 'called 10'
# 'months 10'
# 'reached 10'
# 'seemed 10'
# 'photos 10'
# 'put 10'
# 'two 10'
# 'doctors 9'
# 'zane 9'
# 'set 9'
# 'seen 9'
# 'days 9'
# 'kept 9'
# 'needed 9'
# 'online 9'
# 'fulston 9'
# 'see 9'
# 'journey 9'
# 'medical 9'
# 'though 9'
# 'attention 9'
# 'went 9'

# %%
from wordcloud import WordCloud as wc
wordcloud1 = wc(width = 1000, height = 500).generate(' '.join(textList))
plt.figure(figsize=(15,8))
plt.imshow(wordcloud1)
plt.axis("off")
plt.show()

# %%
textList.collocations()
# Out:
# breast cancer; paulette leaphart; reconstructive surgery; could n't;
# new orleans; double mastectomy; care center; seven months; north
# carolina; tested positive; n't want; 're going; medical records;
# social media; 5,000 month; long-lost love; miles day; day care;
# criminal record; hostile unsafe

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures() # obtains bigram association measures


finder = BigramCollocationFinder.from_words(words_string, 5) # finds bigrams in the text
finder.apply_freq_filter(5) #removes bigrams that appear less than 5 times
bigrams = finder.nbest(bigram_measures.likelihood_ratio, 1000) #obtain the bigrams with the highest likelihood ratio
print('\n'.join('%s %s' % v for v in bigrams)) #printing them out
# Out:
# breast cancer
# reconstructive surgery
# need need
# medical records
# new orleans
# could n't
# need woman
# paulette leaphart
# care center
# 're going
# n't want
# day center
# miles day
# one woman
# cancer treatment
# paulette paulette
# day care
# story need
# leaphart walk
# day posted
# purpose said
# would walk
# mccarty n't
# said going
# n't know
# ashia said
# years said
# said said
# help n't
# said needed
# paulette story
# johnson said
# one day
# said home
# smith said
# told story
# said god
# beyoncé paulette
# paulette even
# paulette journey
# paulette tell
# zane paulette
# paulette told
# months paulette
# paulette charlotte
# walk paulette
# said paulette
# paulette often
# god said
# cancer paulette
# mccarty said
# way paulette
# said daughter
# said wanted
# cancer breast
# asked paulette
# paulette facebook
# walked paulette
# said told
# paulette one
# paulette walk
# mccarty paulette
# said facebook
# johnson paulette
# paulette johnson
# paulette breast
# one paulette
# said woman
# paulette daughter
# n't paulette
# day said
# cancer said
# said n't
# facebook paulette
# said one
# paulette took
# paulette wanted
# daughter paulette
# paulette made
# said cancer
# said day
# n't n't
# paulette day
# paulette would
# woman paulette
# cancer n't
# could paulette
# told paulette
# cancer cancer
# said walk
# walk said
# story paulette
# paulette n't
# paulette said
# n't said
# said story
# story said
# paulette cancer

# %%
# fdist.plot(50, cumulative =False)

# %% [markdown]
# #### Determining the window size

# %%
# If we are interested in examining the surrounding context of a particular word in the text, we need to decide on the parameters of that context.
# If, for example, we are interested in three words that precede a particular word and three words after then we are interested in a 7-word window size.
# This window size can be established as follows:
ngrams = [words_string[i:i+7] for i in range(len(words_string)-6)]# http://digitalhistoryhacks.blogspot.com/2006/08/easy-pieces-in-python-keyword-in.html
    
kwicdict = {}           # opens up a kwicdict        
for n in ngrams: #indexes the fourth word in a sliding window of 7 (three words on each side) 
    if n[3] not in kwicdict: 
        kwicdict[n[3]] = [n]
    else:
        kwicdict[n[3]].append(n)
        
for n in kwicdict['cancer']: # nicely formatted output for the word we are interested in determining the context for
    outstring = ' '.join(n[:3]).rjust(30) #output as a string and right justify first three words in the sliding window
    outstring += str(n[3]).center(len(n[3])+6) # output as a string and center fourth word in the sliding window
    outstring += ' '.join(n[4:]) # output as a string last three words in the sliding window of 7 consecutive words in the text
    print(outstring)
# Out:
# washington.and topless.the breast   cancer   survivor screamed cure
#            face highest breast   cancer   mortality rate inspired
#     inconsistencies found past   cancer   treatment much actually
#             lost sister breast   cancer   tears fell told
#            pink touched breast   cancer   five years october
#           paulette lead breast   cancer   sucks breast cancer
#            cancer sucks breast   cancer   sucks also sang
#             lost mother breast   cancer   know alive would
#               2013 tell breast   cancer   doctors later confirmed
#          lowest point fighting   cancer   said daughter pushed
#                 're going beat   cancer   promised kept highway
#              mounted two years   cancer   treatment choose roof
#        struggles long predated   cancer   years paulette said
#                god woke breast   cancer   half dozen civil
#          later revealed breast   cancer   facebook mccarty n't
#            paulette never even   cancer   double mastectomy elective
#             father 've battled   cancer   friends lost disease
#             shares story talks   cancer   left breast left
#              shows also talked   cancer   metastasizing organs body
#           seen paulette breast   cancer   right breast claims
#            right breast claims   cancer   lies.paulette 0.7 tumor
#           gotten slight margin   cancer   cells left behind
#            said family history   cancer   aggressive approach understood
#         doctors describe stage   cancer   based surgeon saw
#        course treatment breast   cancer   deeply personal decision
#           seen paulette breast   cancer   right breast claims
#            right breast claims   cancer   lies.but exactly treatment
#        remains unclear details   cancer   evolved.members team pulled
#   doctor appointments happened   cancer   said liver could
#  adams mother-in-law diagnosed   cancer   adams saw chemo
#        stage aggressive breast   cancer   'in words spread
#           mention took 'breaks   cancer   treatment travel leisure
#     insider connections breast   cancer   foundation best-selling erotic-fiction
#         complained much paying   cancer   medications zane proposed
#      years.she followed battle   cancer   pneumonia ailments paulette
#              n't walk recorded   cancer   blocked minutes facebook
#      leaphart diagnosed breast   cancer   january 2014 unable
#         paulette story centers   cancer   struck seven months
#              issues mom breast   cancer   asked felt daughter
#         double mastectomy told   cancer   fell months double
#          told anderson houston   cancer   treatment suggested stay
#              stay seattle took   cancer   center discuss treatment
#            doctor telling sign   cancer   said herded office
#         interpreted mean never   cancer   said moment felt
#        left overhearing throes   cancer   battle n't marry
#           called cummings told   cancer   struggling financially cummings
#              people never sick   cancer   incensed paulette daughter
#            saying walked spoke   cancer   women health faith
#         know paulette finances   cancer   struck said bringing
#               need cure breast   cancer   sucks addressing crowdshe
#               lost one breasts   cancer   said later woman
#      treatments survive breast   cancer   exploitation ... got
#       friends including breast   cancer   surgeon saw maclin
#             mother died breast   cancer   recorded song always
#      treatments survive breast   cancer   maclin said exploitation
#       messageone leader breast   cancer   activism n't want
#          likely receive breast   cancer   diagnoses early stage
# diagnosis triple-negative breast   cancer   means cancer cells
#            breast cancer means   cancer   cells n't receptors
#        therapies lowest breast   cancer   survival rate ethnic
#       group according american   cancer   society centers disease
# insurance comprehensive american   cancer   society report says.furthermore
#      made shaping conversation   cancer   country.but another activist
#         women stage metastatic   cancer   women whose cancer
#             cancer women whose   cancer   spread organs usually
#       successfully prayed away   cancer   said activist unfriended
#            point feared kidney   cancer   asked people pray
#              arm return breast   cancer   supporters overwhelmed prayers
#         sign petition proposed   cancer   relief bill written
#       johnson diagnosed breast   cancer   paulette cousin monique
#              going sudden came   cancer   johnson said really
#       billion medical research   cancer   diseases.paulette took facebook
#                 side want cure   cancer   affordable health care
#                said needed pay   cancer   treatments 're preaching
#      made shaping conversation   cancer   country touched many
#        produced feeding breast   cancer   longer knew believe
#           said removed ovaries   cancer   later reported.in weeks
#         career court judgments   cancer   treatment got reply
#         embodiment things pink   cancer   would put hit

# %% [markdown]
# # Named Entities Extraction

# %%
nltk.download("punkt") # downloads punkt tokenizer models
nltk.download('averaged_perceptron_tagger') # downloads the algorithm for predicting the part of speech information
nltk.download('maxent_ne_chunker') # downloads the maximum entropy chunker that has been trained on the ACE 2004 corpus https://catalog.ldc.upenn.edu/LDC2005T09
from nltk import word_tokenize, pos_tag, ne_chunk #imports a word tokenizer, part of speech tagger and named entity tagger
# Out:
# [nltk_data] Downloading package punkt to /home/harish/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/harish/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /home/harish/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!

# %%
#function for extracting named entities:
def extract_entity_names(t, entity_type): # this function has been defined here: https://gist.github.com/onyxfish/322906
    entity_names = []

    if hasattr(t, 'label') and t.label:
        if t.label() == entity_type:
            entity_names.append(' '.join([child[0] for child in t]))
        else:
            for child in t:
                entity_names.extend(extract_entity_names(child, entity_type))

    return entity_names

# %%
# sentence tokenization
sentences = nltk.sent_tokenize(data)
sentences[:5]
# Out:
# ['(CNN) Behind the double-mastectomy scars that run across her bare chest, she had a story to tell.So late last April, Paulette Leaphart embarked on a 1,000-mile walk from her childhood hometown of Biloxi, Mississippi, to the halls of Congress in Washington.And she did it topless.The breast cancer survivor screamed for a cure and demanded better and more affordable health care.',
#  'She wanted women without breasts to believe in their beauty and be proud of their strength.',
#  'By showcasing and embracing her scars, she hoped to inspire others to do the same.Her journey was bold, visual, moving.',
#  "It offered a hero to admire and, given Paulette's audacious decision to walk shirtless in the face of strangers, a rich spectacle to witness.",
#  'It spoke to African-American women, who face the highest breast cancer mortality rate.']

# %%
len(sentences)
# Out:
# 589

# %%
# word tokenization
words = [nltk.word_tokenize(sent) for sent in sentences] # rather than tokenizing the entire file that has been converted into a string, this function tokenizes each of the sentence -- the sentence boundaries are maintained

# %%
words[:20]
# Out:
# [['(',
#   'CNN',
#   ')',
#   'Behind',
#   'the',
#   'double-mastectomy',
#   'scars',
#   'that',
#   'run',
#   'across',
#   'her',
#   'bare',
#   'chest',
#   ',',
#   'she',
#   'had',
#   'a',
#   'story',
#   'to',
#   'tell.So',
#   'late',
#   'last',
#   'April',
#   ',',
#   'Paulette',
#   'Leaphart',
#   'embarked',
#   'on',
#   'a',
#   '1,000-mile',
#   'walk',
#   'from',
#   'her',
#   'childhood',
#   'hometown',
#   'of',
#   'Biloxi',
#   ',',
#   'Mississippi',
#   ',',
#   'to',
#   'the',
#   'halls',
#   'of',
#   'Congress',
#   'in',
#   'Washington.And',
#   'she',
#   'did',
#   'it',
#   'topless.The',
#   'breast',
#   'cancer',
#   'survivor',
#   'screamed',
#   'for',
#   'a',
#   'cure',
#   'and',
#   'demanded',
#   'better',
#   'and',
#   'more',
#   'affordable',
#   'health',
#   'care',
#   '.'],
#  ['She',
#   'wanted',
#   'women',
#   'without',
#   'breasts',
#   'to',
#   'believe',
#   'in',
#   'their',
#   'beauty',
#   'and',
#   'be',
#   'proud',
#   'of',
#   'their',
#   'strength',
#   '.'],
#  ['By',
#   'showcasing',
#   'and',
#   'embracing',
#   'her',
#   'scars',
#   ',',
#   'she',
#   'hoped',
#   'to',
#   'inspire',
#   'others',
#   'to',
#   'do',
#   'the',
#   'same.Her',
#   'journey',
#   'was',
#   'bold',
#   ',',
#   'visual',
#   ',',
#   'moving',
#   '.'],
#  ['It',
#   'offered',
#   'a',
#   'hero',
#   'to',
#   'admire',
#   'and',
#   ',',
#   'given',
#   'Paulette',
#   "'s",
#   'audacious',
#   'decision',
#   'to',
#   'walk',
#   'shirtless',
#   'in',
#   'the',
#   'face',
#   'of',
#   'strangers',
#   ',',
#   'a',
#   'rich',
#   'spectacle',
#   'to',
#   'witness',
#   '.'],
#  ['It',
#   'spoke',
#   'to',
#   'African-American',
#   'women',
#   ',',
#   'who',
#   'face',
#   'the',
#   'highest',
#   'breast',
#   'cancer',
#   'mortality',
#   'rate',
#   '.'],
#  ['It', 'inspired', 'legions', 'of', 'survivors', '.'],
#  ['And',
#   'it',
#   'spoke',
#   'to',
#   'many',
#   'who',
#   "'d",
#   'lost',
#   'someone',
#   'to',
#   'the',
#   'disease.It',
#   'seemed',
#   'a',
#   'storyteller',
#   "'s",
#   'dream',
#   '.'],
#  ['But',
#   'reality',
#   'would',
#   'eventually',
#   'intrude.Documentary',
#   'filmmakers',
#   'were',
#   'first',
#   'to',
#   'seize',
#   'on',
#   'Paulette',
#   "'s",
#   'potential',
#   '--',
#   'after',
#   'she',
#   'approached',
#   'a',
#   'producer',
#   'who',
#   'was',
#   'out',
#   'on',
#   'a',
#   'shoot',
#   ',',
#   'lifted',
#   'up',
#   'her',
#   'shirt',
#   'and',
#   'said',
#   'her',
#   'story',
#   'needed',
#   'to',
#   'be',
#   'told',
#   '.'],
#  ['A',
#   'stunning',
#   'trailer',
#   'for',
#   '``',
#   'Scar',
#   'Story',
#   ',',
#   "''",
#   'in',
#   'which',
#   'the',
#   'film',
#   'crew',
#   'would',
#   'follow',
#   'her',
#   'entire',
#   'walk',
#   ',',
#   'was',
#   'released',
#   'in',
#   'late',
#   'October',
#   '2015.A',
#   'Kickstarter',
#   'campaign',
#   'to',
#   'help',
#   'fund',
#   'the',
#   'film',
#   'went',
#   'up',
#   'weeks',
#   'before',
#   'the',
#   'walk',
#   'began',
#   ',',
#   'attracting',
#   'enthusiastic',
#   'donors',
#   '.'],
#  ['Journalists',
#   'flocked',
#   'to',
#   'Paulette',
#   ',',
#   'eager',
#   'to',
#   'tell',
#   'her',
#   'story',
#   '.'],
#  ['Even',
#   'megastar',
#   'Beyoncé',
#   'took',
#   'notice',
#   'and',
#   'featured',
#   'Paulette',
#   'in',
#   '``',
#   'Lemonade',
#   '.'],
#  ['``',
#   'I',
#   'saw',
#   'the',
#   'trailer',
#   'on',
#   'Facebook',
#   'and',
#   ',',
#   'like',
#   'so',
#   'many',
#   'others',
#   ',',
#   'was',
#   'hooked',
#   '.'],
#  ['In',
#   'a',
#   'world',
#   'hungry',
#   'for',
#   'heroes',
#   ',',
#   'whose',
#   'stories',
#   'of',
#   'inspiration',
#   'bring',
#   'us',
#   'light',
#   'amid',
#   'darkness',
#   ',',
#   'Paulette',
#   'seemed',
#   'to',
#   'feed',
#   'that',
#   'craving',
#   '.'],
#  ['After',
#   'making',
#   'a',
#   'few',
#   'calls',
#   'and',
#   'learning',
#   'she',
#   'was',
#   'walking',
#   'with',
#   'her',
#   '8-year-old',
#   'daughter',
#   ',',
#   'no',
#   'less',
#   ',',
#   'I',
#   'hopped',
#   'in',
#   'my',
#   'car',
#   ',',
#   'picked',
#   'up',
#   'my',
#   'amateur',
#   'photographer',
#   'stepson',
#   ',',
#   'and',
#   'headed',
#   'to',
#   'North',
#   'Carolina',
#   'to',
#   'walk',
#   'with',
#   'her.Some',
#   'stories',
#   'land',
#   'on',
#   'a',
#   'journalist',
#   "'s",
#   'plate',
#   'like',
#   'manna',
#   'from',
#   'heaven',
#   '.'],
#  ['They',
#   "'re",
#   'perfect',
#   'morsels',
#   'you',
#   'ca',
#   "n't",
#   'wait',
#   'to',
#   'share',
#   '.'],
#  ['Others',
#   'arrive',
#   'a',
#   'mess',
#   'of',
#   'ingredients',
#   'with',
#   'no',
#   'recipe',
#   'to',
#   'follow',
#   '.'],
#  ['This',
#   'one',
#   'started',
#   'the',
#   'first',
#   'way',
#   'and',
#   'finished',
#   'the',
#   'other.After',
#   'walking',
#   'with',
#   'Paulette',
#   'for',
#   'a',
#   'full',
#   'day',
#   ',',
#   'I',
#   'left',
#   'with',
#   'more',
#   'questions',
#   'than',
#   'answers',
#   '.'],
#  ['No',
#   'matter',
#   'how',
#   'much',
#   'I',
#   'hated',
#   'to',
#   'admit',
#   'it',
#   ',',
#   'aspects',
#   'of',
#   'her',
#   'story',
#   'simply',
#   'did',
#   "n't",
#   'add',
#   'up',
#   '.'],
#  ['And',
#   'the',
#   'more',
#   'I',
#   'kept',
#   'digging',
#   ',',
#   'the',
#   'more',
#   'inconsistencies',
#   'I',
#   'found',
#   ':',
#   'about',
#   'her',
#   'past',
#   'and',
#   'her',
#   'cancer',
#   'treatment',
#   ',',
#   'about',
#   'how',
#   'much',
#   'she',
#   'was',
#   'actually',
#   'walking',
#   ',',
#   'even',
#   'about',
#   'her',
#   'motivations.Part',
#   'of',
#   'me',
#   'wanted',
#   'to',
#   'walk',
#   'away',
#   '--',
#   'from',
#   'Paulette',
#   'and',
#   'the',
#   'story',
#   '.'],
#  ['If',
#   'even',
#   'one',
#   'woman',
#   "'s",
#   'life',
#   'was',
#   'saved',
#   'thanks',
#   'to',
#   'a',
#   'conversation',
#   'Paulette',
#   'started',
#   ',',
#   'was',
#   "n't",
#   'that',
#   'enough',
#   '?']]

# %%
tagged_sentences = [nltk.pos_tag(word) for word in words] # for each sentence in words (sentence boundaries are maintained in words) assign the most probable part of speech for each word in the sentence

# %%
tagged_sentences
# Out:
# [[('(', '('),
#   ('CNN', 'NNP'),
#   (')', ')'),
#   ('Behind', 'IN'),
#   ('the', 'DT'),
#   ('double-mastectomy', 'JJ'),
#   ('scars', 'NNS'),
#   ('that', 'WDT'),
#   ('run', 'VBP'),
#   ('across', 'IN'),
#   ('her', 'PRP$'),
#   ('bare', 'NN'),
#   ('chest', 'NN'),
#   (',', ','),
#   ('she', 'PRP'),
#   ('had', 'VBD'),
#   ('a', 'DT'),
#   ('story', 'NN'),
#   ('to', 'TO'),
#   ('tell.So', 'VB'),
#   ('late', 'JJ'),
#   ('last', 'JJ'),
#   ('April', 'NNP'),
#   (',', ','),
#   ('Paulette', 'NNP'),
#   ('Leaphart', 'NNP'),
#   ('embarked', 'VBD'),
#   ('on', 'IN'),
#   ('a', 'DT'),
#   ('1,000-mile', 'JJ'),
#   ('walk', 'NN'),
#   ('from', 'IN'),
#   ('her', 'PRP$'),
#   ('childhood', 'NN'),
#   ('hometown', 'NN'),
#   ('of', 'IN'),
#   ('Biloxi', 'NNP'),
#   (',', ','),
#   ('Mississippi', 'NNP'),
#   (',', ','),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('halls', 'NNS'),
#   ('of', 'IN'),
#   ('Congress', 'NNP'),
#   ('in', 'IN'),
#   ('Washington.And', 'NNP'),
#   ('she', 'PRP'),
#   ('did', 'VBD'),
#   ('it', 'PRP'),
#   ('topless.The', 'VB'),
#   ('breast', 'NN'),
#   ('cancer', 'NN'),
#   ('survivor', 'NN'),
#   ('screamed', 'VBD'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('cure', 'NN'),
#   ('and', 'CC'),
#   ('demanded', 'VBD'),
#   ('better', 'JJR'),
#   ('and', 'CC'),
#   ('more', 'RBR'),
#   ('affordable', 'JJ'),
#   ('health', 'NN'),
#   ('care', 'NN'),
#   ('.', '.')],
#  [('She', 'PRP'),
#   ('wanted', 'VBD'),
#   ('women', 'NNS'),
#   ('without', 'IN'),
#   ('breasts', 'NNS'),
#   ('to', 'TO'),
#   ('believe', 'VB'),
#   ('in', 'IN'),
#   ('their', 'PRP$'),
#   ('beauty', 'NN'),
#   ('and', 'CC'),
#   ('be', 'VB'),
#   ('proud', 'NNS'),
#   ('of', 'IN'),
#   ('their', 'PRP$'),
#   ('strength', 'NN'),
#   ('.', '.')],
#  [('By', 'IN'),
#   ('showcasing', 'VBG'),
#   ('and', 'CC'),
#   ('embracing', 'VBG'),
#   ('her', 'PRP$'),
#   ('scars', 'NNS'),
#   (',', ','),
#   ('she', 'PRP'),
#   ('hoped', 'VBD'),
#   ('to', 'TO'),
#   ('inspire', 'VB'),
#   ('others', 'NNS'),
#   ('to', 'TO'),
#   ('do', 'VB'),
#   ('the', 'DT'),
#   ('same.Her', 'NN'),
#   ('journey', 'NN'),
#   ('was', 'VBD'),
#   ('bold', 'JJ'),
#   (',', ','),
#   ('visual', 'JJ'),
#   (',', ','),
#   ('moving', 'VBG'),
#   ('.', '.')],
#  [('It', 'PRP'),
#   ('offered', 'VBD'),
#   ('a', 'DT'),
#   ('hero', 'NN'),
#   ('to', 'TO'),
#   ('admire', 'VB'),
#   ('and', 'CC'),
#   (',', ','),
#   ('given', 'VBN'),
#   ('Paulette', 'NNP'),
#   ("'s", 'POS'),
#   ('audacious', 'JJ'),
#   ('decision', 'NN'),
#   ('to', 'TO'),
#   ('walk', 'VB'),
#   ('shirtless', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('face', 'NN'),
#   ('of', 'IN'),
#   ('strangers', 'NNS'),
#   (',', ','),
#   ('a', 'DT'),
#   ('rich', 'JJ'),
#   ('spectacle', 'NN'),
#   ('to', 'TO'),
#   ('witness', 'VB'),
#   ('.', '.')],
#  [('It', 'PRP'),
#   ('spoke', 'VBD'),
#   ('to', 'TO'),
#   ('African-American', 'JJ'),
#   ('women', 'NNS'),
#   (',', ','),
#   ('who', 'WP'),
#   ('face', 'VBP'),
#   ('the', 'DT'),
#   ('highest', 'JJS'),
#   ('breast', 'NN'),
#   ('cancer', 'NN'),
#   ('mortality', 'NN'),
#   ('rate', 'NN'),
#   ('.', '.')],
#  [('It', 'PRP'),
#   ('inspired', 'VBD'),
#   ('legions', 'NNS'),
#   ('of', 'IN'),
#   ('survivors', 'NNS'),
#   ('.', '.')],
#  [('And', 'CC'),
#   ('it', 'PRP'),
#   ('spoke', 'VBD'),
#   ('to', 'TO'),
#   ('many', 'JJ'),
#   ('who', 'WP'),
#   ("'d", 'MD'),
#   ('lost', 'VB'),
#   ('someone', 'NN'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('disease.It', 'NN'),
#   ('seemed', 'VBD'),
#   ('a', 'DT'),
#   ('storyteller', 'NN'),
#   ("'s", 'POS'),
#   ('dream', 'NN'),
#   ('.', '.')],
#  [('But', 'CC'),
#   ('reality', 'NN'),
#   ('would', 'MD'),
#   ('eventually', 'RB'),
#   ('intrude.Documentary', 'JJ'),
#   ('filmmakers', 'NNS'),
#   ('were', 'VBD'),
#   ('first', 'RB'),
#   ('to', 'TO'),
#   ('seize', 'VB'),
#   ('on', 'IN'),
#   ('Paulette', 'NNP'),
#   ("'s", 'POS'),
#   ('potential', 'NN'),
#   ('--', ':'),
#   ('after', 'IN'),
#   ('she', 'PRP'),
#   ('approached', 'VBD'),
#   ('a', 'DT'),
#   ('producer', 'NN'),
#   ('who', 'WP'),
#   ('was', 'VBD'),
#   ('out', 'RP'),
#   ('on', 'IN'),
#   ('a', 'DT'),
#   ('shoot', 'NN'),
#   (',', ','),
#   ('lifted', 'VBD'),
#   ('up', 'RP'),
#   ('her', 'PRP$'),
#   ('shirt', 'NN'),
#   ('and', 'CC'),
#   ('said', 'VBD'),
#   ('her', 'PRP$'),
#   ('story', 'NN'),
#   ('needed', 'VBN'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('told', 'VBN'),
#   ('.', '.')],
#  [('A', 'DT'),
#   ('stunning', 'JJ'),
#   ('trailer', 'NN'),
#   ('for', 'IN'),
#   ('``', '``'),
#   ('Scar', 'NNP'),
#   ('Story', 'NNP'),
#   (',', ','),
#   ("''", "''"),
#   ('in', 'IN'),
#   ('which', 'WDT'),
#   ('the', 'DT'),
#   ('film', 'NN'),
#   ('crew', 'NN'),
#   ('would', 'MD'),
#   ('follow', 'VB'),
#   ('her', 'PRP$'),
#   ('entire', 'JJ'),
#   ('walk', 'NN'),
#   (',', ','),
#   ('was', 'VBD'),
#   ('released', 'VBN'),
#   ('in', 'IN'),
#   ('late', 'JJ'),
#   ('October', 'NNP'),
#   ('2015.A', 'CD'),
#   ('Kickstarter', 'NNP'),
#   ('campaign', 'NN'),
#   ('to', 'TO'),
#   ('help', 'VB'),
#   ('fund', 'VB'),
#   ('the', 'DT'),
#   ('film', 'NN'),
#   ('went', 'VBD'),
#   ('up', 'RP'),
#   ('weeks', 'NNS'),
#   ('before', 'IN'),
#   ('the', 'DT'),
#   ('walk', 'NN'),
#   ('began', 'VBD'),
#   (',', ','),
#   ('attracting', 'VBG'),
#   ('enthusiastic', 'JJ'),
#   ('donors', 'NNS'),
#   ('.', '.')],
#  [('Journalists', 'NNS'),
#   ('flocked', 'VBD'),
#   ('to', 'TO'),
#   ('Paulette', 'NNP'),
#   (',', ','),
#   ('eager', 'JJ'),
#   ('to', 'TO'),
#   ('tell', 'VB'),
#   ('her', 'PRP$'),
#   ('story', 'NN'),
#   ('.', '.')],
#  [('Even', 'RB'),
#   ('megastar', 'NN'),
#   ('Beyoncé', 'NNP'),
#   ('took', 'VBD'),
#   ('notice', 'NN'),
#   ('and', 'CC'),
#   ('featured', 'VBD'),
#   ('Paulette', 'NNP'),
#   ('in', 'IN'),
#   ('``', '``'),
#   ('Lemonade', 'NNP'),
#   ('.', '.')],
#  [('``', '``'),
#   ('I', 'PRP'),
#   ('saw', 'VBD'),
#   ('the', 'DT'),
#   ('trailer', 'NN'),
#   ('on', 'IN'),
#   ('Facebook', 'NNP'),
#   ('and', 'CC'),
#   (',', ','),
#   ('like', 'IN'),
#   ('so', 'RB'),
#   ('many', 'JJ'),
#   ('others', 'NNS'),
#   (',', ','),
#   ('was', 'VBD'),
#   ('hooked', 'VBN'),
#   ('.', '.')],
#  [('In', 'IN'),
#   ('a', 'DT'),
#   ('world', 'NN'),
#   ('hungry', 'NN'),
#   ('for', 'IN'),
#   ('heroes', 'NNS'),
#   (',', ','),
#   ('whose', 'WP$'),
#   ('stories', 'NNS'),
#   ('of', 'IN'),
#   ('inspiration', 'NN'),
#   ('bring', 'VBP'),
#   ('us', 'PRP'),
#   ('light', 'JJ'),
#   ('amid', 'IN'),
#   ('darkness', 'NN'),
#   (',', ','),
#   ('Paulette', 'NNP'),
#   ('seemed', 'VBD'),
#   ('to', 'TO'),
#   ('feed', 'VB'),
#   ('that', 'DT'),
#   ('craving', 'NN'),
#   ('.', '.')],
#  [('After', 'IN'),
#   ('making', 'VBG'),
#   ('a', 'DT'),
#   ('few', 'JJ'),
#   ('calls', 'NNS'),
#   ('and', 'CC'),
#   ('learning', 'VBG'),
#   ('she', 'PRP'),
#   ('was', 'VBD'),
#   ('walking', 'VBG'),
#   ('with', 'IN'),
#   ('her', 'PRP$'),
#   ('8-year-old', 'JJ'),
#   ('daughter', 'NN'),
#   (',', ','),
#   ('no', 'DT'),
#   ('less', 'NN'),
#   (',', ','),
#   ('I', 'PRP'),
#   ('hopped', 'VBD'),
#   ('in', 'IN'),
#   ('my', 'PRP$'),
#   ('car', 'NN'),
#   (',', ','),
#   ('picked', 'VBD'),
#   ('up', 'RP'),
#   ('my', 'PRP$'),
#   ('amateur', 'NN'),
#   ('photographer', 'NN'),
#   ('stepson', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('headed', 'VBD'),
#   ('to', 'TO'),
#   ('North', 'NNP'),
#   ('Carolina', 'NNP'),
#   ('to', 'TO'),
#   ('walk', 'VB'),
#   ('with', 'IN'),
#   ('her.Some', 'JJ'),
#   ('stories', 'NNS'),
#   ('land', 'VBP'),
#   ('on', 'IN'),
#   ('a', 'DT'),
#   ('journalist', 'NN'),
#   ("'s", 'POS'),
#   ('plate', 'NN'),
#   ('like', 'IN'),
#   ('manna', 'NN'),
#   ('from', 'IN'),
#   ('heaven', 'NN'),
#   ('.', '.')],
#  [('They', 'PRP'),
#   ("'re", 'VBP'),
#   ('perfect', 'JJ'),
#   ('morsels', 'NNS'),
#   ('you', 'PRP'),
#   ('ca', 'MD'),
#   ("n't", 'RB'),
#   ('wait', 'VB'),
#   ('to', 'TO'),
#   ('share', 'NN'),
#   ('.', '.')],
#  [('Others', 'NNS'),
#   ('arrive', 'VBP'),
#   ('a', 'DT'),
#   ('mess', 'NN'),
#   ('of', 'IN'),
#   ('ingredients', 'NNS'),
#   ('with', 'IN'),
#   ('no', 'DT'),
#   ('recipe', 'NN'),
#   ('to', 'TO'),
#   ('follow', 'VB'),
#   ('.', '.')],
#  [('This', 'DT'),
#   ('one', 'CD'),
#   ('started', 'VBD'),
#   ('the', 'DT'),
#   ('first', 'JJ'),
#   ('way', 'NN'),
#   ('and', 'CC'),
#   ('finished', 'VBD'),
#   ('the', 'DT'),
#   ('other.After', 'NN'),
#   ('walking', 'VBG'),
#   ('with', 'IN'),
#   ('Paulette', 'NNP'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('full', 'JJ'),
#   ('day', 'NN'),
#   (',', ','),
#   ('I', 'PRP'),
#   ('left', 'VBD'),
#   ('with', 'IN'),
#   ('more', 'RBR'),
#   ('questions', 'NNS'),
#   ('than', 'IN'),
#   ('answers', 'NNS'),
#   ('.', '.')],
#  [('No', 'DT'),
#   ('matter', 'NN'),
#   ('how', 'WRB'),
#   ('much', 'JJ'),
#   ('I', 'PRP'),
#   ('hated', 'VBD'),
#   ('to', 'TO'),
#   ('admit', 'VB'),
#   ('it', 'PRP'),
#   (',', ','),
#   ('aspects', 'VBZ'),
#   ('of', 'IN'),
#   ('her', 'PRP$'),
#   ('story', 'NN'),
#   ('simply', 'RB'),
#   ('did', 'VBD'),
#   ("n't", 'RB'),
#   ('add', 'VB'),
#   ('up', 'RP'),
#   ('.', '.')],
#  [('And', 'CC'),
#   ('the', 'DT'),
#   ('more', 'JJR'),
#   ('I', 'PRP'),
#   ('kept', 'VBD'),
#   ('digging', 'VBG'),
#   (',', ','),
#   ('the', 'DT'),
#   ('more', 'JJR'),
#   ('inconsistencies', 'NNS'),
#   ('I', 'PRP'),
#   ('found', 'VBD'),
#   (':', ':'),
#   ('about', 'IN'),
#   ('her', 'PRP$'),
#   ('past', 'NN'),
#   ('and', 'CC'),
#   ('her', 'PRP$'),
#   ('cancer', 'NN'),
#   ('treatment', 'NN'),
#   (',', ','),
#   ('about', 'IN'),
#   ('how', 'WRB'),
#   ('much', 'JJ'),
#   ('she', 'PRP'),
#   ('was', 'VBD'),
#   ('actually', 'RB'),
#   ('walking', 'VBG'),
#   (',', ','),
#   ('even', 'RB'),
#   ('about', 'IN'),
#   ('her', 'PRP$'),
#   ('motivations.Part', 'NN'),
#   ('of', 'IN'),
#   ('me', 'PRP'),
#   ('wanted', 'VBD'),
#   ('to', 'TO'),
#   ('walk', 'VB'),
#   ('away', 'RB'),
#   ('--', ':'),
#   ('from', 'IN'),
#   ('Paulette', 'NNP'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('story', 'NN'),
#   ('.', '.')],
#  [('If', 'IN'),
#   ('even', 'RB'),
#   ('one', 'CD'),
#   ('woman', 'NN'),
#   ("'s", 'POS'),
#   ('life', 'NN'),
#   ('was', 'VBD'),
#   ('saved', 'VBN'),
#   ('thanks', 'NNS'),
#   ('to', 'TO'),
#   ('a', 'DT'),
#   ('conversation', 'NN'),
#   ('Paulette', 'NNP'),
#   ('started', 'VBD'),
#   (',', ','),
#   ('was', 'VBD'),
#   ("n't", 'RB'),
#   ('that', 'IN'),
#   ('enough', 'RB'),
#   ('?', '.')],
#  [('So', 'RB'),
#   ('what', 'WP'),
#   ('if', 'IN'),
#   ('our', 'PRP$'),
#   ('hero', 'NN'),
#   ('was', 'VBD'),
#   ('flawed', 'VBN'),
#   ('?', '.'),
#   ('But', 'CC'),
#   ('then', 'RB'),
#   ('I', 'PRP'),
#   ('thought', 'VBD'),
#   ('about', 'IN'),
#   ('the', 'DT'),
#   ('thousands', 'NNS'),
#   ('of', 'IN'),
#   ('people', 'NNS'),
#   ('following', 'VBG'),
#   ('Paulette', 'NNP'),
#   ('on', 'IN'),
#   ('Facebook', 'NNP'),
#   (',', ','),
#   ('all', 'PDT'),
#   ('the', 'DT'),
#   ('journalists', 'NNS'),
#   ('who', 'WP'),
#   ('covered', 'VBD'),
#   ('her', 'PRP$'),
#   ('journey', 'NN'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('online', 'JJ'),
#   ('video', 'NN'),
#   ('viewed', 'VBD'),
#   ('more', 'JJR'),
#   ('than', 'IN'),
#   ('20', 'CD'),
#   ('million', 'CD'),
#   ('times.And', 'NN'),
#   ('I', 'PRP'),
#   ('realized', 'VBD'),
#   (':', ':'),
#   ('This', 'DT'),
#   ('story', 'NN'),
#   ('was', 'VBD'),
#   ("n't", 'RB'),
#   ('just', 'RB'),
#   ('about', 'IN'),
#   ('Paulette', 'NNP'),
#   ('.', '.')],
#  [('It', 'PRP'),
#   ("'s", 'VBZ'),
#   ('about', 'IN'),
#   ('our', 'PRP$'),
#   ('need', 'NN'),
#   ('to', 'TO'),
#   ('find', 'VB'),
#   ('--', ':'),
#   ('and', 'CC'),
#   (',', ','),
#   ('for', 'IN'),
#   ('some', 'DT'),
#   ('of', 'IN'),
#   ('us', 'PRP'),
#   (',', ','),
#   ('become', 'VB'),
#   ('--', ':'),
#   ('heroes', 'NNS'),
#   ('.', '.')],
#  [('It', 'PRP'),
#   ("'s", 'VBZ'),
#   ('about', 'IN'),
#   ('the', 'DT'),
#   ('unchecked', 'JJ'),
#   ('storytelling', 'NN'),
#   ('and', 'CC'),
#   ('self-promotion', 'NN'),
#   ('that', 'WDT'),
#   ('thrives', 'VBZ'),
#   ('on', 'IN'),
#   ('social', 'JJ'),
#   ('media', 'NNS'),
#   ('.', '.')],
#  [('It', 'PRP'),
#   ("'s", 'VBZ'),
#   ('about', 'IN'),
#   ('the', 'DT'),
#   ('disappointment', 'NN'),
#   ('we', 'PRP'),
#   ('feel', 'VBP'),
#   ('when', 'WRB'),
#   ('reality', 'NN'),
#   ('jolts', 'NNS'),
#   ('us', 'PRP'),
#   ('awake', 'VBP'),
#   ('from', 'IN'),
#   ('our', 'PRP$'),
#   ('reverie.In', 'NN'),
#   ('our', 'PRP$'),
#   ('desperation', 'NN'),
#   ('to', 'TO'),
#   ('believe', 'VB'),
#   ('in', 'IN'),
#   ('people', 'NNS'),
#   (',', ','),
#   ('do', 'VBP'),
#   ('we', 'PRP'),
#   ('dole', 'VB'),
#   ('out', 'RP'),
#   ('passes', 'NNS'),
#   ('too', 'RB'),
#   ('easily', 'RB'),
#   ('?', '.')],
#  [('Had', 'NNP'),
#   ('we', 'PRP'),
#   (',', ','),
#   ('in', 'IN'),
#   ('our', 'PRP$'),
#   ('collective', 'JJ'),
#   ('enchantment', 'NN'),
#   ('with', 'IN'),
#   ('Paulette', 'NNP'),
#   (',', ','),
#   ('all', 'DT'),
#   ('become', 'VBP'),
#   ('blind', 'IN'),
#   ('?', '.'),
#   ('Shameka', 'NNP'),
#   ('Fulston', 'NNP'),
#   (',', ','),
#   ('left', 'VBD'),
#   (',', ','),
#   ('and', 'CC'),
#   ('others', 'NNS'),
#   ('join', 'VBP'),
#   ('Paulette', 'NNP'),
#   ('Leaphart', 'NNP'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('community', 'NN'),
#   ('walk', 'NN'),
#   ('in', 'IN'),
#   ('Charlotte', 'NNP'),
#   ('.', '.')],
#  [('Fulston', 'NNP'),
#   ('planned', 'VBD'),
#   ('to', 'TO'),
#   ('rejoin', 'VB'),
#   ('Paulette', 'NNP'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('last', 'JJ'),
#   ('100', 'CD'),
#   ('miles', 'NNS'),
#   ('of', 'IN'),
#   ('her', 'PRP$'),
#   ('walk', 'NN'),
#   ('but', 'CC'),
#   ('left', 'VBD'),
#   ('Charlotte', 'NNP'),
#   ('feeling', 'VBG'),
#   ('disenchanted.A', 'JJ'),
#   ('vision', 'NN'),
#   ('from', 'IN'),
#   ('GodI', 'NNP'),
#   ('caught', 'VBD'),
#   ('up', 'RP'),
#   ('with', 'IN'),
#   ('Paulette', 'NNP'),
#   ('at', 'IN'),
#   ('a', 'DT'),
#   ('house', 'NN'),
#   ('outside', 'IN'),
#   ('Charlotte', 'NNP'),
#   (',', ','),
#   ('North', 'NNP'),
#   ('Carolina', 'NNP'),
#   (',', ','),
#   ('where', 'WRB'),
#   ('she', 'PRP'),
#   ('and', 'CC'),
#   ('her', 'PRP$'),
#   ('daughter', 'NN'),
#   ('were', 'VBD'),
#   ('staying', 'VBG'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('grill', 'NN'),
#   ('was', 'VBD'),
#   ('fired', 'VBN'),
#   ('up', 'RP'),
#   (',', ','),
#   ('food', 'NN'),
#   ('filled', 'VBD'),
#   ('the', 'DT'),
#   ('counters', 'NNS'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('music', 'NN'),
#   ('was', 'VBD'),
#   ('pumping', 'VBG'),
#   ('.', '.')],
#  [('Paulette', 'NNP'),
#   (',', ','),
#   ('who', 'WP'),
#   ('wore', 'VBD'),
#   ('a', 'DT'),
#   ('T-shirt', 'NN'),
#   ('emblazoned', 'VBN'),
#   ('with', 'IN'),
#   ('the', 'DT'),
#   ('words', 'NNS'),
#   ('``', '``'),
#   ('Living', 'NNP'),
#   ('beautifully', 'RB'),
#   (',', ','),
#   ("''", "''"),
#   ('greeted', 'VBD'),
#   ('me', 'PRP'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('hug', 'NN'),
#   ('.', '.')],
#  [('``', '``'),
#   ('The', 'DT'),
#   ('walk', 'NN'),
#   ('has', 'VBZ'),
#   ('given', 'VBN'),
#   ('me', 'PRP'),
#   ('back', 'RB'),
#   ('everything', 'NN'),
#   ('the', 'DT'),
#   ('devil', 'JJ'),
#   ('stole', 'NN'),
#   ('from', 'IN'),
#   ('me', 'PRP'),
#   (',', ','),
#   ("''", "''"),
#   ('she', 'PRP'),
#   ('told', 'VBD'),
#   ('those', 'DT'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('room', 'NN'),
#   (',', ','),
#   ('as', 'IN'),
#   ('they', 'PRP'),
#   ('gathered', 'VBD'),
#   ('to', 'TO'),
#   ('pray', 'VB'),
#   ('for', 'IN'),
#   ('her', 'PRP$'),
#   ('journey.The', 'NN'),
#   ('hostess', 'NN'),
#   ('said', 'VBD'),
#   ('she', 'PRP'),
#   ('opened', 'VBD'),
#   ('her', 'PRP'),
#   ('home', 'NN'),
#   ('because', 'IN'),
#   ('she', 'PRP'),
#   ("'d", 'MD'),
#   ('lost', 'VB'),
#   ('her', 'PRP$'),
#   ('own', 'JJ'),
#   ('sister', 'NN'),
#   ('to', 'TO'),
#   ('breast', 'VB'),
#   ('cancer', 'NN'),
#   ('.', '.')],
#  [('As', 'IN'),
#   ('her', 'PRP$'),
#   ('tears', 'NNS'),
#   ('fell', 'VBD'),
#   (',', ','),
#   ('she', 'PRP'),
#   ('told', 'VBD'),
#   ('Paulette', 'NNP'),
#   (',', ','),
#   ('``', '``'),
#   ('That', 'DT'),
#   ("'s", 'VBZ'),
#   ('why', 'WRB'),
#   ('I', 'PRP'),
#   ('wanted', 'VBD'),
#   ('to', 'TO'),
#   ('take', 'VB'),
#   ('care', 'NN'),
#   ('of', 'IN'),
#   ('you', 'PRP'),
#   ('.', '.')],
#  [('``', '``'),
#   ('Dusk', 'NN'),
#   ('turned', 'VBD'),
#   ('to', 'TO'),
#   ('night', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('I', 'PRP'),
#   ('kept', 'VBD'),
#   ('my', 'PRP$'),
#   ('eye', 'NN'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('time', 'NN'),
#   ('.', '.')],
#  [('When', 'WRB'),
#   ('we', 'PRP'),
#   ('spoke', 'VBD'),
#   ('by', 'IN'),
#   ('phone', 'NN'),
#   (',', ','),
#   ('Paulette', 'NNP'),
#   ('had', 'VBD'),
#   ('warned', 'VBN'),
#   ('me', 'PRP'),
#   ('she', 'PRP'),
#   ('woke', 'VBD'),
#   ('up', 'RB'),
#   ('at', 'IN'),
#   ('4:30', 'CD'),
#   ('each', 'DT'),
#   ('morning', 'NN'),
#   ('and', 'CC'),
#   ('walked', 'VBD'),
#   ('20', 'CD'),
#   ('to', 'TO'),
#   ('40', 'CD'),
#   ('miles', 'NNS'),
#   ('each', 'DT'),
#   ('day', 'NN'),
#   ('except', 'IN'),
#   ('weekends', 'NNS'),
#   (',', ','),
#   ('which', 'WDT'),
#   ('were', 'VBD'),
#   ('for', 'IN'),
#   ('rest', 'NN'),
#   ('.', '.')],
#  [('She', 'PRP'),
#   ('had', 'VBD'),
#   ('to', 'TO'),
#   ('cover', 'VB'),
#   ('that', 'DT'),
#   ('sort', 'NN'),
#   ('of', 'IN'),
#   ('ground', 'NN'),
#   (',', ','),
#   ('she', 'PRP'),
#   ('explained', 'VBD'),
#   (',', ','),
#   ('if', 'IN'),
#   ('she', 'PRP'),
#   ('wanted', 'VBD'),
#   ('to', 'TO'),
#   ('meet', 'VB'),
#   ('her', 'PRP$'),
#   ('goal', 'NN'),
#   ('of', 'IN'),
#   ('reaching', 'VBG'),
#   ('Washington', 'NNP'),
#   ('by', 'IN'),
#   ('June', 'NNP'),
#   ('27', 'CD'),
#   (',', ','),
#   ('her', 'PRP'),
#   ('50th', 'JJ'),
#   ('birthday', 'NN'),
#   ('.', '.')],
#  [('I', 'PRP'),
#   ("'m", 'VBP'),
#   ('in', 'IN'),
#   ('decent', 'JJ'),
#   ('shape', 'NN'),
#   (',', ','),
#   ('but', 'CC'),
#   ('walking', 'VBG'),
#   ('at', 'IN'),
#   ('least', 'JJS'),
#   ('20', 'CD'),
#   ('miles', 'NNS'),
#   ('on', 'IN'),
#   ('little', 'JJ'),
#   ('sleep', 'NN'),
#   ('scared', 'VBD'),
#   ('me', 'PRP'),
#   ('.', '.')],
#  [('``', '``'),
#   ('Oh', 'UH'),
#   (',', ','),
#   ('we', 'PRP'),
#   ("'re", 'VBP'),
#   ('not', 'RB'),
#   ('starting', 'VBG'),
#   ("'til", 'PRP'),
#   ('9', 'CD'),
#   ('a.m.', 'RB'),
#   ('tomorrow', 'NN'),
#   (',', ','),
#   ("''", "''"),
#   ('Paulette', 'NNP'),
#   ('finally', 'RB'),
#   ('told', 'VBD'),
#   ('me', 'PRP'),
#   ('as', 'IN'),
#   ('the', 'DT'),
#   ('night', 'NN'),
#   ('wore', 'NN'),
#   ('on', 'IN'),
#   ('.', '.')],
#  [('A', 'DT'),
#   ('community', 'NN'),
#   ('walk', 'NN'),
#   ('was', 'VBD'),
#   ('planned', 'VBN'),
#   ('in', 'IN'),
#   ('downtown', 'NN'),
#   ('Charlotte', 'NNP'),
#   ('.', '.')],
#  [('I', 'PRP'),
#   ('breathed', 'VBD'),
#   ('a', 'DT'),
#   ('sigh', 'NN'),
#   ('of', 'IN'),
#   ('relief.The', 'JJ'),
#   ('next', 'JJ'),
#   ('morning', 'NN'),
#   (',', ','),
#   ('the', 'DT'),
#   ('crowd', 'NN'),
#   ('was', 'VBD'),
#   ('passionate', 'JJ'),
#   ('but', 'CC'),
#   ('small', 'JJ'),
#   ('--', ':'),
#   ('about', 'IN'),
#   ('three', 'CD'),
#   ('dozen', 'NN'),
#   ('women', 'NNS'),
#   (',', ','),
#   ('men', 'NNS'),
#   ('and', 'CC'),
#   ('children', 'NNS'),
#   ('.', '.')],
#  [('Many', 'JJ'),
#   ('wore', 'RB'),
#   ('pink', 'VBP'),
#   (',', ','),
#   ('and', 'CC'),
#   ('most', 'JJS'),
#   ('had', 'VBD'),
#   ('been', 'VBN'),
#   ('touched', 'VBN'),
#   ('by', 'IN'),
#   ('breast', 'NN'),
#   ('cancer', 'NN'),
#   ('.', '.')],
#  [('``', '``'),
#   ('Five', 'CD'),
#   ('years', 'NNS'),
#   ('in', 'IN'),
#   ('October', 'NNP'),
#   (',', ','),
#   ("''", "''"),
#   ('said', 'VBD'),
#   ('one', 'CD'),
#   ('woman', 'NN'),
#   ('.', '.')],
#  [('``', '``'),
#   ('Nine', 'CD'),
#   ('years', 'NNS'),
#   ('cancer-free', 'JJ'),
#   (',', ','),
#   ("''", "''"),
#   ('said', 'VBD'),
#   ('another', 'DT'),
#   (',', ','),
#   ('sporting', 'VBG'),
#   ('a', 'DT'),
#   ('``', '``'),
#   ('Fight', 'NNP'),
#   ('Like', 'IN'),
#   ('a', 'DT'),
#   ('Girl', 'NNP'),
#   ("''", "''"),
#   ('T-shirt', 'NN'),
#   ('.', '.')],
#  [('``', '``'),
#   ('Mom', 'NNP'),
#   ('died', 'VBD'),
#   ('in', 'IN'),
#   ('2004', 'CD'),
#   (',', ','),
#   ("''", "''"),
#   ('said', 'VBD'),
#   ('one', 'CD'),
#   ('man', 'NN'),
#   (',', ','),
#   ('who', 'WP'),
#   ('survived', 'VBD'),
#   ('lymphoma', 'NN'),
#   ('himself.A', 'NN'),
#   ('woman', 'NN'),
#   ('who', 'WP'),
#   ("'d", 'VBD'),
#   ('driven', 'VBN'),
#   ('through', 'IN'),
#   ('the', 'DT'),
#   ('night', 'NN'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('here', 'RB'),
#   ('took', 'VBD'),
#   ('off', 'RP'),
#   ('her', 'PRP$'),
#   ('shirt', 'NN'),
#   ('to', 'TO'),
#   ('reveal', 'VB'),
#   ('her', 'PRP$'),
#   ('own', 'JJ'),
#   ('tangled', 'JJ'),
#   ('scars', 'NNS'),
#   ('.', '.')],
#  [('She', 'PRP'),
#   ("'d", 'MD'),
#   ('seen', 'VBN'),
#   ('Paulette', 'NNP'),
#   ('in', 'IN'),
#   ('Atlanta', 'NNP'),
#   ('and', 'CC'),
#   ('vowed', 'VBD'),
#   ('to', 'TO'),
#   ('walk', 'VB'),
#   ('with', 'IN'),
#   ('her.After', 'NN'),
#   ('photos', 'NNS'),
#   (',', ','),
#   ('videos', 'NNS'),
#   ('and', 'CC'),
#   ('prayers', 'NNS'),
#   (',', ','),
#   ('the', 'DT'),
#   ('walkers', 'NNS'),
#   ('hit', 'VBD'),
#   ('the', 'DT'),
#   ('pavement', 'NN'),
#   (',', ','),
#   ('weaving', 'VBG'),
#   ('their', 'PRP$'),
#   ('way', 'NN'),
#   ('through', 'IN'),
#   ('downtown', 'NN'),
#   ('.', '.')],
#  [('``', '``'),
#   ('We', 'PRP'),
#   ('need', 'VBP'),
#   ('a', 'DT'),
#   ('cure', 'NN'),
#   ('!', '.')],
#  [('We', 'PRP'),
#   ('need', 'VBP'),
#   ('a', 'DT'),
#   ('cure', 'NN'),
#   ('!', '.'),
#   ("''", "''")],
#  [('they', 'PRP'),
#   ('screamed', 'VBD'),
#   (',', ','),
#   ('following', 'VBG'),
#   ('Paulette', 'NNP'),
#   ("'s", 'POS'),
#   ('lead', 'NN'),
#   ('.', '.')],
#  [('``', '``'),
#   ('Breast', 'NNP'),
#   ('cancer', 'NN'),
#   ('sucks', 'VBZ'),
#   ('!', '.')],
#  [('Breast', 'NNP'),
#   ('cancer', 'NN'),
#   ('sucks', 'VBZ'),
#   ('!', '.'),
#   ("''", "''")],
#  [('They', 'PRP'),
#   ('also', 'RB'),
#   ('sang', 'VBD'),
#   ('hymns', 'NN'),
#   ('.', '.')],
#  [('``', '``'),
#   ('We', 'PRP'),
#   ('will', 'MD'),
#   ('walk', 'VB'),
#   ('until', 'IN'),
#   ('we', 'PRP'),
#   ('defeat', 'VBP'),
#   ('this', 'DT'),
#   ('demon', 'NN'),
#   ('!', '.'),
#   ("''", "''")],
#  [('Paulette', 'NNP'),
#   ('yelled.All', 'VBZ'),
#   ('the', 'DT'),
#   ('pain', 'NN'),
#   ('I', 'PRP'),
#   ('felt', 'VBD'),
#   ('from', 'IN'),
#   ('the', 'DT'),
#   ('day', 'NN'),
#   ('I', 'PRP'),
#   ('was', 'VBD'),
#   ('born', 'VBN'),
#   ('had', 'VBD'),
#   ('purpose', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('I', 'PRP'),
#   ("'m", 'VBP'),
#   ('living', 'VBG'),
#   ('that', 'IN'),
#   ('purpose', 'NN'),
#   ('.', '.')],
#  [('God', 'NNP'),
#   ('said', 'VBD'),
#   ('I', 'PRP'),
#   ("'m", 'VBP'),
#   ('going', 'VBG'),
#   ('to', 'TO'),
#   ('use', 'VB'),
#   ('your', 'PRP$'),
#   ('chest', 'NN'),
#   ('.', '.')],
#  [('Paulette', 'NNP'),
#   ('LeaphartIt', 'NNP'),
#   ('was', 'VBD'),
#   ('Memorial', 'NNP'),
#   ('Day', 'NNP'),
#   (',', ','),
#   ('one', 'CD'),
#   ('month', 'NN'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('day', 'NN'),
#   ('since', 'IN'),
#   ('she', 'PRP'),
#   ('started', 'VBD'),
#   (',', ','),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('streets', 'NNS'),
#   ('were', 'VBD'),
#   ('quiet', 'JJ'),
#   ('.', '.')],
#  [('Occasional', 'JJ'),
#   ('onlookers', 'NNS'),
#   ('gawked', 'VBD'),
#   (',', ','),
#   ('wondering', 'VBG'),
#   ('what', 'WP'),
#   ('the', 'DT'),
#   ('commotion', 'NN'),
#   ('was', 'VBD'),
#   ('about', 'RB'),
#   ('.', '.')],
#  [('I', 'PRP'),
#   ('walked', 'VBD'),
#   ('along', 'RB'),
#   ('taking', 'VBG'),
#   ('notes', 'NNS'),
#   ('and', 'CC'),
#   ('wondered', 'VBD'),
#   ('myself', 'PRP'),
#   (':', ':'),
#   ('How', 'WRB'),
#   ('effective', 'JJ'),
#   ('was', 'VBD'),
#   ('this', 'DT'),
#   ('small', 'JJ'),
#   (',', ','),
#   ('1-mile', 'JJ'),
#   ('march', 'NN'),
#   (',', ','),
#   ('really', 'RB'),
#   ('?', '.'),
#   ('I', 'PRP'),
#   ('was', 'VBD'),
#   ('more', 'RBR'),
#   ('interested', 'JJ'),
#   ('in', 'IN'),
#   ('what', 'WP'),
#   ('would', 'MD'),
#   ('come', 'VB'),
#   ('next', 'JJ'),
#   (':', ':'),
#   ('the', 'DT'),
#   ('walk', 'NN'),
#   ('she', 'PRP'),
#   ('was', 'VBD'),
#   ('resuming', 'VBG'),
#   ('with', 'IN'),
#   ('her', 'PRP$'),
#   ('daughter', 'NN'),
#   ('to', 'TO'),
#   ('reach', 'VB'),
#   ('Washington', 'NNP'),
#   ('in', 'IN'),
#   ('less', 'JJR'),
#   ('than', 'IN'),
#   ('a', 'DT'),
#   ('month.They', 'NN'),
#   ('had', 'VBD'),
#   ('already', 'RB'),
#   ('covered', 'VBN'),
#   ('710', 'CD'),
#   ('miles', 'NNS'),
#   ('.', '.')],
#  [('They', 'PRP'),
#   ("'d", 'MD'),
#   ('walked', 'VB'),
#   ('all', 'DT'),
#   ('but', 'CC'),
#   ('100', 'CD'),
#   ('of', 'IN'),
#   ('them', 'PRP'),
#   (',', ','),
#   ('Paulette', 'NNP'),
#   ('said', 'VBD'),
#   ('.', '.')],
#  [('She', 'PRP'),
#   ('said', 'VBD'),
#   ('she', 'PRP'),
#   ('often', 'RB'),
#   ('used', 'VBD'),
#   ('cabs', 'NNS'),
#   ('to', 'TO'),
#   ('carry', 'VB'),
#   ('her', 'PRP$'),
#   ('through', 'IN'),
#   ('dangerous', 'JJ'),
#   ('parts', 'NNS'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('journey', 'NN'),
#   ('.', '.')],
#  [('With', 'IN'),
#   ('most', 'JJS'),
#   ('weekends', 'NNS'),
#   ('off', 'RP'),
#   (',', ','),
#   ('that', 'WDT'),
#   ('would', 'MD'),
#   ('mean', 'VB'),
#   ('they', 'PRP'),
#   ("'d", 'MD'),
#   ('averaged', 'VBD'),
#   ('more', 'JJR'),
#   ('than', 'IN'),
#   ('27', 'CD'),
#   ('miles', 'NNS'),
#   ('a', 'DT'),
#   ('day', 'NN'),
#   ('on', 'IN'),
#   ('foot.We', 'NN'),
#   ('got', 'VBD'),
#   ('started', 'VBN'),
#   ('around', 'IN'),
#   ('noon', 'NN'),
#   ('.', '.')],
#  [('I', 'PRP'),
#   ("'d", 'MD'),
#   ('pictured', 'VBN'),
#   ('us', 'PRP'),
#   ('rambling', 'VBG'),
#   ('through', 'IN'),
#   ('rolling', 'VBG'),
#   ('hills', 'NNS'),
#   ('of', 'IN'),
#   ('green', 'JJ'),
#   ('.', '.')],
#  [('Paulette', 'NNP'),
#   ('would', 'MD'),
#   ('be', 'VB'),
#   ('like', 'IN'),
#   ('Forrest', 'NNP'),
#   ('Gump', 'NNP'),
#   (',', ','),
#   ('I', 'PRP'),
#   ('thought', 'VBD'),
#   (',', ','),
#   ('gathering', 'VBG'),
#   ('disciples', 'NNS'),
#   ('as', 'IN'),
#   ('she', 'PRP'),
#   ('strode', 'VBD'),
#   ('through', 'IN'),
#   ('quaint', 'NN'),
#   ('towns.Paulette', 'NN'),
#   ('preferred', 'VBD'),
#   ('a', 'DT'),
#   ('busier', 'NN'),
#   ('route', 'NN'),
#   ('and', 'CC'),
#   ('steered', 'VBD'),
#   ('us', 'PRP'),
#   ('toward', 'IN'),
#   ('US', 'NNP'),
#   ('29', 'CD'),
#   ('.', '.')],
#  [('In', 'IN'),
#   ('her', 'PRP$'),
#   ('mind', 'NN'),
#   ('it', 'PRP'),
#   ('was', 'VBD'),
#   ('safer', 'VBN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('only', 'RB'),
#   ('along', 'RB'),
#   ('highways', 'NNS'),
#   ('could', 'MD'),
#   ('she', 'PRP'),
#   ('and', 'CC'),
#   ('her', 'PRP$'),
#   ('message', 'NN'),
#   ('be', 'VB'),
#   ('seen', 'VBN'),
#   ('.', '.')],
#  [('She', 'PRP'),
#   ('carried', 'VBD'),
#   ('no', 'DT'),
#   ('sign', 'NN'),
#   (',', ','),
#   ('insisting', 'VBG'),
#   ('the', 'DT'),
#   ('scars', 'NNS'),
#   ('told', 'VBD'),
#   ('her', 'PRP'),
#   ('story.To', 'VBD'),
#   ('her', 'PRP'),
#   ('5,000', 'CD'),
#   ('friends', 'NNS'),
#   ('and', 'CC'),
#   ('thousands', 'NNS'),
#   ('more', 'RBR'),
#   ('followers', 'NNS'),
#   ('on', 'IN'),
#   ('Facebook', 'NNP'),
#   (',', ','),
#   ('Paulette', 'NNP'),
#   ('was', 'VBD'),
#   ('already', 'RB'),
#   ('a', 'DT'),
#   ('hero', 'NN'),
#   ('.', '.')],
#  [('They', 'PRP'),
#   ('showered', 'VBD'),
#   ('her', 'PRP'),
#   ('with', 'IN'),
#   ('love', 'NN'),
#   ('and', 'CC'),
#   ('praise', 'NN'),
#   ('.', '.')],
#  [('``', '``'),
#   ('If', 'IN'),
#   ('I', 'PRP'),
#   ('had', 'VBD'),
#   ('10,000', 'CD'),
#   ('thousand', 'NN'),
#   ('tongues', 'NNS'),
#   (',', ','),
#   ('I', 'PRP'),
#   ('could', 'MD'),
#   ("n't", 'RB'),
#   ('thank', 'VB'),
#   ('you', 'PRP'),
#   ('enough', 'RB'),
#   (',', ','),
#   ("''", "''"),
#   ('one', 'CD'),
#   ('person', 'NN'),
#   ('wrote', 'VBD'),
#   ('the', 'DT'),
#   ('day', 'NN'),
#   ('after', 'IN'),
#   ('I', 'PRP'),
#   ('walked', 'VBD'),
#   ('with', 'IN'),
#   ('her', 'PRP'),
#   ('.', '.')],
#  [('``', '``'),
#   ('I', 'PRP'),
#   ('understand', 'VBP'),
#   ('your', 'PRP$'),
#   ('fight', 'NN'),
#   ('!', '.')],
#  [('God', 'NNP'),
#   ('is', 'VBZ'),
#   ('with', 'IN'),
#   ('you', 'PRP'),
#   ('every', 'DT'),
#   ('step', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('way', 'NN'),
#   ('.', '.')],
#  [('``', '``'),
#   ('``', '``'),
#   ('I', 'PRP'),
#   ('love', 'VBP'),
#   ('you', 'PRP'),
#   ('for', 'IN'),
#   ('what', 'WP'),
#   ('you', 'PRP'),
#   ('are', 'VBP'),
#   ('doing', 'VBG'),
#   (',', ','),
#   ("''", "''"),
#   ('wrote', 'VBD'),
#   ('another', 'DT'),
#   ('.', '.')],
#  [('``', '``'),
#   ('You', 'PRP'),
#   ('are', 'VBP'),
#   ('so', 'RB'),
#   ('brave', 'IN'),
#   ('you', 'PRP'),
#   ('are', 'VBP'),
#   ('my', 'PRP$'),
#   ('WOMAN', 'NNP'),
#   ('OF', 'IN'),
#   ('THE', 'NNP'),
#   ('YEAR', 'NNP'),
#   ('.', '.')],
#  [('``', '``'),
#   ('``', '``'),
#   ('You', 'PRP'),
#   ('are', 'VBP'),
#   ('such', 'JJ'),
#   ('a', 'DT'),
#   ('phenomenal', 'JJ'),
#   ('woman', 'NN'),
#   (',', ','),
#   ("''", "''"),
#   ('wrote', 'VBD'),
#   ('a', 'DT'),
#   ('third', 'JJ'),
#   ('.', '.')],
#  [('``', '``'),
#   ('I', 'PRP'),
#   ('lost', 'VBD'),
#   ('my', 'PRP$'),
#   ('mother', 'NN'),
#   ('to', 'TO'),
#   ('breast', 'NN'),
#   ('cancer', 'NN'),
#   ('but', 'CC'),
#   ('I', 'PRP'),
#   ('know', 'VBP'),
#   ('if', 'IN'),
#   ('she', 'PRP'),
#   ('were', 'VBD'),
#   ('alive', 'JJ'),
#   (',', ','),
#   ('she', 'PRP'),
#   ('would', 'MD'),
#   ('be', 'VB'),
#   ('walking', 'VBG'),
#   ('with', 'IN'),
#   ('you', 'PRP'),
#   ('--', ':'),
#   ('the', 'DT'),
#   ('whole', 'JJ'),
#   ('way', 'NN'),
#   ('.', '.')],
#  [('...', ':'), ('God', 'NNP'), ('bless', 'NN'), ('you', 'PRP'), ('.', '.')],
#  [('``', '``'),
#   ('Paulette', 'NNP'),
#   ('has', 'VBZ'),
#   ('inspired', 'VBN'),
#   ('women', 'NNS'),
#   ('all', 'DT'),
#   ('over', 'IN'),
#   ('the', 'DT'),
#   ('world', 'NN'),
#   ('and', 'CC'),
#   ('said', 'VBD'),
#   ('she', 'PRP'),
#   ('has', 'VBZ'),
#   ('even', 'RB'),
#   ('saved', 'VBN'),
#   ('lives', 'NNS'),
#   ('.', '.')],
#  [('People', 'NNS'),
#   ('who', 'WP'),
#   ("'d", 'VBD'),
#   ('been', 'VBN'),
#   ('considering', 'VBG'),
#   ('suicide', 'NN'),
#   (',', ','),
#   ('she', 'PRP'),
#   ('said', 'VBD'),
#   (',', ','),
#   ('were', 'VBD'),
#   ('motivated', 'VBN'),
#   ('by', 'IN'),
#   ('her', 'PRP'),
#   ('to', 'TO'),
#   ('go', 'VB'),
#   ('on.The', 'RB'),
#   ('global', 'JJ'),
#   ('attention', 'NN'),
#   ('began', 'VBD'),
#   ('two', 'CD'),
#   ('years', 'NNS'),
#   ('earlier', 'RBR'),
#   (',', ','),
#   ('when', 'WRB'),
#   (',', ','),
#   ('over', 'IN'),
#   ('Labor', 'NNP'),
#   ('Day', 'NNP'),
#   ('weekend', 'NN'),
#   (',', ','),
#   ('she', 'PRP'),
#   ('posted', 'VBD'),
#   ('topless', 'JJ'),
#   ('photos', 'NNS'),
#   ('of', 'IN'),
#   ('herself', 'NN'),
#   ('on', 'IN'),
#   ('a', 'DT'),
#   ('beach', 'NN'),
#   ('in', 'IN'),
#   ('Mississippi', 'NNP'),
#   ('.', '.')],
#  [('She', 'PRP'),
#   ('had', 'VBD'),
#   ('just', 'RB'),
#   ('emerged', 'VBN'),
#   ('from', 'IN'),
#   ('eight', 'CD'),
#   ('months', 'NNS'),
#   ('of', 'IN'),
#   ('depression', 'NN'),
#   ('after', 'IN'),
#   ('losing', 'VBG'),
#   ('her', 'PRP$'),
#   ('breasts', 'NNS'),
#   ('and', 'CC'),
#   ('being', 'VBG'),
#   ('told', 'VBN'),
#   ('she', 'PRP'),
#   ('could', 'MD'),
#   ("n't", 'RB'),
#   ('have', 'VB'),
#   ('reconstructive', 'JJ'),
#   ('surgery', 'NN'),
#   ('because', 'IN'),
#   ('of', 'IN'),
#   ('a', 'DT'),
#   ('pre-existing', 'JJ'),
#   ('blood-clotting', 'JJ'),
#   ('disorder', 'NN'),
#   ('.', '.')],
#  [('She', 'PRP'),
#   ('says', 'VBZ'),
#   ('she', 'PRP'),
#   ('had', 'VBD'),
#   ('a', 'DT'),
#   ('vision', 'NN'),
#   ('from', 'IN'),
#   ('God', 'NNP'),
#   ('to', 'TO'),
#   ('go', 'VB'),
#   ('to', 'TO'),
#   ('Biloxi', 'NNP'),
#   ('Beach', 'NNP'),
#   (',', ','),
#   ('take', 'VB'),
#   ('off', 'RP'),
#   ('her', 'PRP$'),
#   ('shirt', 'NN'),
#   ('and', 'CC'),
#   ('be', 'VB'),
#   ('photographed.She', 'VBN'),
#   ('said', 'VBD'),
#   ('people', 'NNS'),
#   ('surrounded', 'VBD'),
#   ('her', 'PRP'),
#   ('.', '.')],
#  [('A', 'DT'),
#   ('woman', 'NN'),
#   ('began', 'VBD'),
#   ('to', 'TO'),
#   ('cry', 'VB'),
#   ('and', 'CC'),
#   ('then', 'RB'),
#   ('she', 'PRP'),
#   ('did', 'VBD'),
#   (',', ','),
#   ('too', 'RB'),
#   ('.', '.')],
#  [('Onlookers', 'NNS'), ('applauded', 'VBD'), ('.', '.')],
#  [('Paulette', 'NNP'),
#   ('freed', 'VBD'),
#   ('herself', 'PRP'),
#   ('in', 'IN'),
#   ('that', 'DT'),
#   ('moment', 'NN'),
#   ('and', 'CC'),
#   (',', ','),
#   ('in', 'IN'),
#   ('posting', 'VBG'),
#   ('photos', 'NNS'),
#   ('on', 'IN'),
#   ('Facebook', 'NNP'),
#   (',', ','),
#   ('did', 'VBD'),
#   ('the', 'DT'),
#   ('same', 'JJ'),
#   ('for', 'IN'),
#   ('others', 'NNS'),
#   ('.', '.')],
#  [('She', 'PRP'),
#   ('said', 'VBD'),
#   ('a', 'DT'),
#   ('man', 'NN'),
#   ('wrote', 'VBD'),
#   ('to', 'TO'),
#   ('thank', 'VB'),
#   ('her', 'PRP'),
#   (',', ','),
#   ('saying', 'VBG'),
#   ('that', 'IN'),
#   ('his', 'PRP$'),
#   ('wife', 'NN'),
#   (',', ','),
#   ('who', 'WP'),
#   ("'d", 'VBD'),
#   ('lost', 'VBN'),
#   ('her', 'PRP$'),
#   ('breasts', 'NNS'),
#   ('years', 'NNS'),
#   ('before', 'IN'),
#   (',', ','),
#   ('had', 'VBD'),
#   ('finally', 'RB'),
#   ('bared', 'VBN'),
#   ('her', 'PRP$'),
#   ('chest', 'NN'),
#   ('for', 'IN'),
#   ('him.She', 'NN'),
#   ('was', 'VBD'),
#   ('chosen', 'VBN'),
#   ('by', 'IN'),
#   ('God', 'NNP'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('a', 'DT'),
#   ('vessel', 'NN'),
#   ('for', 'IN'),
#   ('his', 'PRP$'),
#   ('work', 'NN'),
#   (',', ','),
#   ('she', 'PRP'),
#   ('said', 'VBD'),
#   (',', ','),
#   ('and', 'CC'),
#   ('her', 'PRP$'),
#   ('photos', 'NNS'),
#   ('were', 'VBD'),
#   ('``', '``'),
#   ('liked', 'VBN'),
#   ("''", "''"),
#   ('almost', 'RB'),
#   ('300,000', 'CD'),
#   ('times', 'NNS'),
#   ('.', '.')],
#  [('It', 'PRP'),
#   ('was', 'VBD'),
#   ('God', 'NNP'),
#   ('who', 'WP'),
#   ('woke', 'VBD'),
#   ('her', 'PRP'),
#   ('up', 'RP'),
#   ('one', 'CD'),
#   ('night', 'NN'),
#   ('in', 'IN'),
#   ('December', 'NNP'),
#   ('2013', 'CD'),
#   ('to', 'TO'),
#   ('tell', 'VB'),
#   ('her', 'PRP$'),
#   ('she', 'PRP'),
#   ('had', 'VBD'),
#   ('breast', 'NN'),
#   ('cancer', 'NN'),
#   (',', ','),
#   ('which', 'WDT'),
#   ('doctors', 'VBZ'),
#   ('later', 'RB'),
#   ('confirmed', 'VBN'),
#   ('.', '.')],
#  [('And', 'CC'),
#   ('it', 'PRP'),
#   ('was', 'VBD'),
#   ('God', 'NNP'),
#   ('who', 'WP'),
#   ('told', 'VBD'),
#   ('her', 'PRP'),
#   ('to', 'TO'),
#   ('go', 'VB'),
#   ('on', 'IN'),
#   ('this', 'DT'),
#   ('1,000-mile', 'JJ'),
#   ('topless', 'NN'),
#   ('walk', 'NN'),
#   ('.', '.')],
#  [('``', '``'),
#   ('All', 'PDT'),
#   ('the', 'DT'),
#   ('pain', 'NN'),
#   ('I', 'PRP'),
#   ('felt', 'VBD'),
#   ('from', 'IN'),
#   ('the', 'DT'),
#   ('day', 'NN'),
#   ('I', 'PRP'),
#   ('was', 'VBD'),
#   ('born', 'VBN'),
#   ('had', 'VBD'),
#   ('purpose', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('I', 'PRP'),
#   ("'m", 'VBP'),
#   ('living', 'VBG'),
#   ('that', 'IN'),
#   ('purpose', 'NN'),
#   (',', ','),
#   ("''", "''"),
#   ('she', 'PRP'),
#   ('said', 'VBD'),
#   ('.', '.')],
#  [('``', '``'),
#   ('God', 'NNP'),
#   ('said', 'VBD'),
#   ('I', 'PRP'),
#   ("'m", 'VBP'),
#   ('going', 'VBG'),
#   ('to', 'TO'),
#   ('use', 'VB'),
#   ('your', 'PRP$'),
#   ('chest', 'NN'),
#   ('.', '.')],
#  [('``', '``'),
#   ('Pushing', 'VBG'),
#   ('her', 'PRP$'),
#   ('daughter', 'NN'),
#   ('in', 'IN'),
#   ('a', 'DT'),
#   ('weighed-down', 'JJ'),
#   ('stroller', 'NN'),
#   (',', ','),
#   ('Paulette', 'NNP'),
#   ('Leaphart', 'NNP'),
#   ('winds', 'VBZ'),
#   ('her', 'PRP$'),
#   ('way', 'NN'),
#   ('out', 'IN'),
#   ('of', 'IN'),
#   ('downtown', 'NN'),
#   ('Charlotte', 'NNP'),
#   ('to', 'TO'),
#   ('continue', 'VB'),
#   ('her', 'PRP$'),
#   ('journey', 'NN'),
#   ('toward', 'IN'),
#   ('Washington.The', 'NNP'),
#   ('first', 'RB'),
#   ('signsBased', 'VBD'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('expressions', 'NNS'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('people', 'NNS'),
#   ('we', 'PRP'),
#   ('passed', 'VBD'),
#   (',', ','),
#   ('not', 'RB'),
#   ('everyone', 'NN'),
#   ('saw', 'VBD'),
#   ('the', 'DT'),
#   ('purpose', 'NN'),
#   ('.', '.')],
#  [('She', 'PRP'),
#   ('joked', 'VBD'),
#   ('that', 'IN'),
#   ('she', 'PRP'),
#   ('must', 'MD'),
#   ('look', 'VB'),
#   ('like', 'IN'),
#   ('a', 'DT'),
#   ('bag', 'NN'),
#   ('lady', 'NN'),
#   ('to', 'TO'),
#   ('some', 'DT'),
#   ('.', '.')],
#  [('Others', 'NNS'),
#   ('got', 'VBD'),
#   ('what', 'WP'),
#   ('this', 'DT'),
#   ('was', 'VBD'),
#   ('about', 'IN'),
#   ('and', 'CC'),
#   ('offered', 'VBD'),
#   ('her', 'PRP$'),
#   ('cheers', 'NNS'),
#   ('and', 'CC'),
#   ('hugs', 'NNS'),
#   ('.', '.')],
#  [('A', 'DT'),
#   ('church', 'NN'),
#   ('group', 'NN'),
#   ('giving', 'VBG'),
#   ('out', 'RP'),
#   ('toiletries', 'NNS'),
#   ('to', 'TO'),
#   ('homeless', 'VB'),
#   ('people', 'NNS'),
#   ('gathered', 'VBD'),
#   ('her', 'PRP'),
#   ('in', 'IN'),
#   ('a', 'DT'),
#   ('circle', 'NN'),
#   ('for', 'IN'),
#   ('prayers', 'NNS'),
#   ('.', '.')],
#  [('Two', 'CD'),
#   ('women', 'NNS'),
#   ('on', 'IN'),
#   ('bikes', 'NNS'),
#   ('who', 'WP'),
#   ("'d", 'VBD'),
#   ('seen', 'VBN'),
#   ('her', 'PRP$'),
#   ('story', 'NN'),
#   ('rode', 'NN'),
#   ('up', 'IN'),
#   ('and', 'CC'),
#   ('passed', 'VBD'),
#   ('her', 'PRP$'),
#   ('$', '$'),
#   ('20', 'CD'),
#   ('bills.Paulette', 'NN'),
#   ('had', 'VBD'),
#   ('said', 'VBD'),
#   ('she', 'PRP'),
#   ('only', 'RB'),
#   ('ate', 'VBP'),
#   ('fruit', 'NN'),
#   ('when', 'WRB'),
#   ('she', 'PRP'),
#   ('walked', 'VBD'),
#   ('.', '.')],
#  [('On', 'IN'),
#   ('this', 'DT'),
#   ('day', 'NN'),
#   (',', ','),
#   ('though', 'RB'),
#   (',', ','),
#   ('she', 'PRP'),
#   ('ate', 'VBD'),
#   ('fried', 'JJ'),
#   ('chicken', 'NN'),
#   ('tenders', 'NNS'),
#   ('from', 'IN'),
#   ('Popeyes', 'NNP'),
#   ('and', 'CC'),
#   ('two', 'CD'),
#   ('hot', 'JJ'),
#   ('dogs', 'NNS'),
#   ('at', 'IN'),
#   ('Cook', 'NNP'),
#   ('Out', 'NNP'),
#   (',', ','),
#   ('a', 'DT'),
#   ('Southern', 'JJ'),
#   ('fast-food', 'NN'),
#   ('chain', 'NN'),
#   ('.', '.')],
#  [('I', 'PRP'),
#   ('was', 'VBD'),
#   ("n't", 'RB'),
#   ('judging', 'VBG'),
#   ('her', 'PRP$'),
#   ('choices', 'NNS'),
#   (';', ':'),
#   ('I', 'PRP'),
#   ('matched', 'VBD'),
#   ('everything', 'NN'),
#   ('she', 'PRP'),
#   ('ate', 'VBD'),
#   ('and', 'CC'),
#   ('then', 'RB'),
#   ('some', 'DT'),
#   ('.', '.')],
#  [('But', 'CC'),
#   ('she', 'PRP'),
#   ('did', 'VBD'),
#   ("n't", 'RB'),
#   ('eat', 'VB'),
#   ('the', 'DT'),
#   ('apple', 'NN'),
#   ('I', 'PRP'),
#   ('offered', 'VBD'),
#   (',', ','),
#   ('and', 'CC'),
#   ('I', 'PRP'),
#   ('never', 'RB'),
#   ('saw', 'VBD'),
#   ('her', 'PRP'),
#   ('eat', 'VB'),
#   ('a', 'DT'),
#   ('piece', 'NN'),
#   ('of', 'IN'),
#   ('fruit.It', 'NN'),
#   ('was', 'VBD'),
#   ('one', 'CD'),
#   ('of', 'IN'),
#   ('those', 'DT'),
#   ('tiny', 'JJ'),
#   (',', ','),
#   ('perhaps', 'RB'),
#   ('silly', 'RB'),
#   (',', ','),
#   ('observations', 'NNS'),
#   ('I', 'PRP'),
#   ('filed', 'VBD'),
#   ('away', 'RB'),
#   ('.', '.')],
#  [('But', 'CC'),
#   ('are', 'VBP'),
#   ("n't", 'RB'),
#   ('we', 'PRP'),
#   ('all', 'DT'),
#   ('guilty', 'JJ'),
#   ('of', 'IN'),
#   ('saying', 'VBG'),
#   ('and', 'CC'),
#   ('doing', 'VBG'),
#   ('different', 'JJ'),
#   ('things', 'NNS'),
#   (',', ','),
#   ('especially', 'RB'),
#   ('when', 'WRB'),
#   ('it', 'PRP'),
#   ('comes', 'VBZ'),
#   ('to', 'TO'),
#   ('diet', 'VB'),
#   ('?', '.'),
#   ('The', 'DT'),
#   ('heat', 'NN'),
#   ('had', 'VBD'),
#   ('slowed', 'VBN'),
#   ('her', 'PRP$'),
#   ('down', 'NN'),
#   ('.', '.')],
#  [('She', 'PRP'),
#   ('said', 'VBD'),
#   ('she', 'PRP'),
#   ('was', 'VBD'),
#   ('now', 'RB'),
#   ('aiming', 'VBG'),
#   ('for', 'IN'),
#   ('20', 'CD'),
#   ('miles', 'NNS'),
#   ('a', 'DT'),
#   ('day', 'NN'),
#   (',', ','),
#   ('news', 'NN'),
#   ('that', 'WDT'),
#   ('came', 'VBD'),
#   ('as', 'IN'),
#   ('a', 'DT'),
#   ('relief', 'NN'),
#   ('.', '.')],
#  [('It', 'PRP'),
#   ('was', 'VBD'),
#   ('late', 'JJ'),
#   ('afternoon', 'NN'),
#   (',', ','),
#   ('though', 'RB'),
#   (',', ','),
#   ('and', 'CC'),
#   ('we', 'PRP'),
#   ('had', 'VBD'),
#   ("n't", 'RB'),
#   ('even', 'RB'),
#   ('gone', 'VBN'),
#   ('10', 'CD'),
#   ('miles', 'NNS'),
#   ('.', '.')],
#  [('Sometimes', 'RB'),
#   ('her', 'PRP$'),
#   ('daughter', 'NN'),
#   ('trudged', 'VBD'),
#   ('along', 'RB'),
#   ('with', 'IN'),
#   ('us', 'PRP'),
#   ('.', '.')],
#  [('More', 'RBR'),
#   ('often', 'RB'),
#   (',', ','),
#   ('she', 'PRP'),
#   ('climbed', 'VBD'),
#   ('into', 'IN'),
#   ('a', 'DT'),
#   ('stroller', 'NN'),
#   ('built', 'NN'),
#   ('for', 'IN'),
#   ('kids', 'NNS'),
#   ('less', 'JJR'),
#   ('than', 'IN'),
#   ('half', 'NN'),
#   ('her', 'PRP$'),
#   ('size', 'NN'),
#   ('.', '.')],
#  [('Bags', 'NNP'),
#   ('spilled', 'VBD'),
#   ('over', 'IN'),
#   ('the', 'DT'),
#   ('sides', 'NNS'),
#   (';', ':'),
#   ('one', 'CD'),
#   ('balanced', 'VBD'),
#   ('across', 'IN'),
#   ('her', 'PRP$'),
#   ('lap', 'NN'),
#   ('.', '.')],
#  [('Several', 'JJ'),
#   ('times', 'NNS'),
#   ('the', 'DT'),
#   ('awkward', 'JJ'),
#   ('contraption', 'NN'),
#   ('tumbled', 'VBD'),
#   ('over', 'RP'),
#   ('when', 'WRB'),
#   ('she', 'PRP'),
#   ('was', 'VBD'),
#   ('getting', 'VBG'),
#   ('in', 'IN'),
#   ('or', 'CC'),
#   ('out.While', 'IN'),
#   ('picking', 'VBG'),
#   ('up', 'RP'),
#   ('her', 'PRP$'),
#   ('scattered', 'JJ'),
#   ('belongings', 'NNS'),
#   ('--', ':'),
#   ('an', 'DT'),
#   ('overstuffed', 'JJ'),
#   ('wallet', 'NN'),
#   (',', ','),
#   ('sunscreen', 'JJ'),
#   ('and', 'CC'),
#   ('bug', 'JJ'),
#   ('spray', 'NN'),
#   (',', ','),
#   ('water', 'NN'),
#   ('bottles', 'NNS'),
#   ('and', 'CC'),
#   ('her', 'PRP$'),
#   ('daughter', 'NN'),
#   ("'s", 'POS'),
#   ('``', '``'),
#   ('Jesus', 'NNP'),
#   ('Storybook', 'NNP'),
#   ('Bible', 'NNP'),
#   ("''", "''"),
#   ('--', ':'),
#   ('Paulette', 'NNP'),
#   ('told', 'VBD'),
#   ('me', 'PRP'),
#   ('she', 'PRP'),
#   ("'d", 'MD'),
#   ('already', 'RB'),
#   ('lost', 'VB'),
#   ('her', 'PRP$'),
#   ('driver', 'NN'),
#   ("'s", 'POS'),
#   ('license', 'NN'),
#   ('and', 'CC'),
#   ('passport', 'NN'),
#   ('.', '.')],
#  [('``', '``'),
#   ('How', 'WRB'),
#   ('do', 'VB'),
#   ('you', 'PRP'),
#   ('check', 'VB'),
#   ('into', 'IN'),
#   ('hotels', 'NNS'),
#   ('?', '.'),
#   ("''", "''")],
#  [('I', 'PRP'),
#   ('asked', 'VBD'),
#   (',', ','),
#   ('knowing', 'VBG'),
#   ('desk', 'NN'),
#   ('clerks', 'NNS'),
#   ('always', 'RB'),
#   ('ask', 'VBP'),
#   ('for', 'IN'),
#   ('ID', 'NNP'),
#   ('.', '.')],
#  [('``', '``'),
#   ('Everyone', 'NN'),
#   ('knows', 'VBZ'),
#   ('who', 'WP'),
#   ('I', 'PRP'),
#   ('am', 'VBP'),
#   (',', ','),
#   ("''", "''"),
#   ('she', 'PRP'),
#   ('answered', 'VBD'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('smile', 'NN'),
#   ('.', '.')],
#  [('I', 'PRP'),
#   ('made', 'VBD'),
#   ('another', 'DT'),
#   ('mental', 'JJ'),
#   ('note.The', 'JJ'),
#   ('highway', 'NN'),
#   ('we', 'PRP'),
#   ('walked', 'VBD'),
#   ('along', 'RB'),
#   ('grew', 'VBD'),
#   ('busy', 'JJ'),
#   ('.', '.')],
#  [('When', 'WRB'),
#   ('Paulette', 'NNP'),
#   ("'s", 'POS'),
#   ('daughter', 'NN'),
#   ('was', 'VBD'),
#   ('out', 'IN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('stroller', 'NN'),
#   (',', ','),
#   ('I', 'PRP'),
#   ('often', 'RB'),
#   ('caught', 'VBD'),
#   ('myself', 'PRP'),
#   ('holding', 'VBG'),
#   ('my', 'PRP$'),
#   ('breath', 'NN'),
#   ('as', 'IN'),
#   ('cars', 'NNS'),
#   ('whizzed', 'VBD'),
#   ('by.In', 'IN'),
#   ('the', 'DT'),
#   ('hottest', 'JJS'),
#   ('part', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('day', 'NN'),
#   (',', ','),
#   ('she', 'PRP'),
#   ('took', 'VBD'),
#   ('breaks', 'NNS'),
#   ('.', '.')],
#  [('Sometimes', 'RB'),
#   (',', ','),
#   ('she', 'PRP'),
#   ('said', 'VBD'),
#   (',', ','),
#   ('she', 'PRP'),
#   ('and', 'CC'),
#   ('her', 'PRP$'),
#   ('daughter', 'NN'),
#   ('studied', 'VBD'),
#   ('.', '.')],
#  [('Other', 'JJ'),
#   ('times', 'NNS'),
#   (',', ','),
#   ('they', 'PRP'),
#   ('found', 'VBD'),
#   ('a', 'DT'),
#   ('place', 'NN'),
#   ('to', 'TO'),
#   ('swim', 'VB'),
#   (',', ','),
#   ('catch', 'VB'),
#   ('a', 'DT'),
#   ('movie', 'NN'),
#   ('or', 'CC'),
#   ('visit', 'VB'),
#   ('a', 'DT'),
#   ('garden', 'NN'),
#   ('.', '.')],
#  [('On', 'IN'),
#   ('the', 'DT'),
#   ('day', 'NN'),
#   ('I', 'PRP'),
#   ('walked', 'VBD'),
#   ('with', 'IN'),
#   ('her', 'PRP'),
#   (',', ','),
#   ('we', 'PRP'),
#   ('went', 'VBD'),
#   ('bowling.Paulette', 'NN'),
#   ('was', 'VBD'),
#   ('on', 'IN'),
#   ('her', 'PRP'),
#   ('phone', 'NN'),
#   ('often', 'RB'),
#   ('and', 'CC'),
#   ('obsessed', 'VBN'),
#   ('with', 'IN'),
#   ('charging', 'VBG'),
#   ('it', 'PRP'),
#   ('wherever', 'IN'),
#   ('we', 'PRP'),
#   ('stopped', 'VBD'),
#   ('.', '.')],
#  [('She', 'PRP'),
#   ('was', 'VBD'),
#   ("n't", 'RB'),
#   ('making', 'VBG'),
#   ('calls', 'NNS'),
#   ('as', 'RB'),
#   ('much', 'RB'),
#   ('as', 'IN'),
#   ('checking', 'VBG'),
#   ('Facebook', 'NNP'),
#   ('.', '.')],
#  [('She', 'PRP'),
#   ('seemed', 'VBD'),
#   ('consumed', 'JJ'),
#   ('with', 'IN'),
#   ('monitoring', 'NN'),
#   ('likes', 'NNS'),
#   (',', ','),
#   ('shares', 'NNS'),
#   ('and', 'CC'),
#   ('comments', 'NNS'),
#   ('.', '.')],
#  [('I', 'PRP'),
#   ('asked', 'VBD'),
#   ('if', 'IN'),
#   ('anyone', 'NN'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('Internet', 'NNP'),
#   ('ever', 'RB'),
#   ('put', 'VBD'),
#   ('her', 'PRP'),
#   ('down.Only', 'RB'),
#   ('one', 'CD'),
#   (',', ','),
#   ('she', 'PRP'),
#   ('said', 'VBD'),
#   (':', ':'),
#   ('a', 'DT'),
#   ('woman', 'NN'),
#   ('she', 'PRP'),
#   ('did', 'VBD'),
#   ("n't", 'RB'),
#   ('know', 'VB'),
#   ('who', 'WP'),
#   ('was', 'VBD'),
#   ('spreading', 'VBG'),
#   ('lies', 'NNS'),
#   ('and', 'CC'),
#   ('had', 'VBD'),
#   ('a', 'DT'),
#   ('criminal', 'JJ'),
#   ('record', 'NN'),
#   ('.', '.')],
#  [('A', 'DT'),
#   ('woman', 'NN'),
#   ('she', 'PRP'),
#   ('suspected', 'VBD'),
#   ('was', 'VBD'),
#   ('crazy', 'JJ'),
#   ('and', 'CC'),
#   ('jealous', 'JJ'),
#   ('.', '.')],
#  [('A', 'DT'),
#   ('woman', 'NN'),
#   ('she', 'PRP'),
#   ('was', 'VBD'),
#   ('determined', 'VBN'),
#   ('to', 'TO'),
#   ('ignore.What', 'VB'),
#   ('about', 'IN'),
#   ('the', 'DT'),
#   ('documentary', 'JJ'),
#   ('group', 'NN'),
#   ('who', 'WP'),
#   ("'d", 'VBZ'),
#   ('set', 'VBN'),
#   ('out', 'RP'),
#   ('to', 'TO'),
#   ('follow', 'VB'),
#   ('her', 'PRP'),
#   ('?', '.')],
#  [('What', 'WP'),
#   ('had', 'VBD'),
#   ('happened', 'VBN'),
#   ('to', 'TO'),
#   ('them', 'PRP'),
#   ('?', '.')],
#  [('Paulette', 'NNP'),
#   ('told', 'VBD'),
#   ('me', 'PRP'),
#   ('they', 'PRP'),
#   ("'d", 'MD'),
#   ('made', 'VBN'),
#   ('money', 'NN'),
#   ('off', 'IN'),
#   ('her', 'PRP$'),
#   ('story', 'NN'),
#   ('without', 'IN'),
#   ('her', 'PRP$'),
#   ('consent', 'NN'),
#   ('and', 'CC'),
#   ('left', 'VBD'),
#   ('after', 'IN'),
#   ('just', 'RB'),
#   ('a', 'DT'),
#   ('few', 'JJ'),
#   ('days', 'NNS'),
#   (',', ','),
#   ('abandoning', 'VBG'),
#   ('her', 'PRP$'),
#   ('and', 'CC'),
#   ('her', 'PRP$'),
#   ('daughter', 'NN'),
#   ('``', '``'),
#   ('like', 'IN'),
#   ('dogs', 'NNS'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('side', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('road', 'NN'),
#   ('.', '.')],
#  [('``', '``'),
#   ('Paulette', 'NNP'),
#   ('often', 'RB'),
#   ('described', 'VBD'),
#   ('her', 'PRP'),
#   ('undertaking', 'NN'),
#   ('as', 'IN'),
#   ('``', '``'),
#   ('a', 'DT'),
#   ('walk', 'NN'),
#   ('of', 'IN'),
#   ('faith', 'NN'),
#   ("''", "''"),
#   ('and', 'CC'),
#   ('said', 'VBD'),
#   ('Jesus', 'NNP'),
#   ('has', 'VBZ'),
#   ('always', 'RB'),
#   ('been', 'VBN'),
#   ('with', 'IN'),
#   ('her', 'PRP'),
#   ('.', '.')],
#  [('When', 'WRB'),
#   ('she', 'PRP'),
#   ('was', 'VBD'),
#   ('a', 'DT'),
#   ('small', 'JJ'),
#   ('child', 'NN'),
#   (',', ','),
#   ('she', 'PRP'),
#   ('said', 'VBD'),
#   (',', ','),
#   ('she', 'PRP'),
#   ('was', 'VBD'),
#   ('sexually', 'RB'),
#   (',', ','),
#   ('physically', 'RB'),
#   ('and', 'CC'),
#   ('emotionally', 'RB'),
#   ('abused', 'VBN'),
#   ('.', '.')],
#  [('Her', 'PRP$'),
#   ('great-grandmother', 'JJ'),
#   ('gave', 'VBD'),
#   ('her', 'PRP'),
#   ('a', 'DT'),
#   ('Bible', 'JJ'),
#   ('.', '.')],
#  [('She', 'PRP'),
#   ('said', 'VBD'),
#   ('it', 'PRP'),
#   ('was', 'VBD'),
#   ('the', 'DT'),
#   ('first', 'JJ'),
#   ('book', 'NN'),
#   ('she', 'PRP'),
#   ('ever', 'RB'),
#   ('read', 'VBD'),
#   ('.', '.')],
#  [('``', '``'),
#   ('She', 'PRP'),
#   ('could', 'MD'),
#   ("n't", 'RB'),
#   ('protect', 'VB'),
#   ('me', 'PRP'),
#   (',', ','),
#   ('but', 'CC'),
#   ('she', 'PRP'),
#   ('gave', 'VBD'),
#   ('me', 'PRP'),
#   ('something', 'NN'),
#   ('that', 'WDT'),
#   ('would', 'MD'),
#   ('.', '.')],
#  [('``', '``'),
#   ('After', 'IN'),
#   ('one', 'CD'),
#   ('particularly', 'RB'),
#   ('brutal', 'JJ'),
#   ('beating', 'NN'),
#   (',', ','),
#   ('Paulette', 'NNP'),
#   ('said', 'VBD'),
#   (',', ','),
#   ('she', 'PRP'),
#   ('promised', 'VBD'),
#   ('God', 'NNP'),
#   ('that', 'IN'),
#   ('if', 'IN'),
#   ('he', 'PRP'),
#   ('let', 'VBD'),
#   ('her', 'PRP'),
#   ('live', 'VB'),
#   (',', ','),
#   ('she', 'PRP'),
#   ("'d", 'MD'),
#   ('dedicate', 'VB'),
#   ('her', 'PRP$'),
#   ('life', 'NN'),
#   ('to', 'TO'),
#   ('taking', 'VBG'),
#   ('care', 'NN'),
#   ('of', 'IN'),
#   ('children', 'NNS'),
#   ('.', '.')],
#  [('She', 'PRP'),
#   ('has', 'VBZ'),
#   ('eight', 'CD'),
#   (';', ':'),
#   ('she', 'PRP'),
#   ('said', 'VBD'),
#   ('she', 'PRP'),
#   ('gave', 'VBD'),
#   ('birth', 'NN'),
#   ('to', 'TO'),
#   ('four', 'CD'),
#   ('and', 'CC'),
#   ('adopted', 'VBD'),
#   ('four', 'CD'),
#   ('others', 'NNS'),
#   ('.', '.')],
#  [('Over', 'IN'),
#   ('the', 'DT'),
#   ('years', 'NNS'),
#   (',', ','),
#   ('she', 'PRP'),
#   ('said', 'VBD'),
#   (',', ','),
#   ('she', 'PRP'),
#   ("'s", 'VBZ'),
#   ('fostered', 'JJ'),
#   ('hundreds', 'NNS'),
#   ('more.Her', 'JJ'),
#   ('older', 'JJR'),
#   ('kids', 'NNS'),
#   ('were', 'VBD'),
#   ('caring', 'VBG'),
#   ('for', 'IN'),
#   ('her', 'PRP$'),
#   ('teens', 'NNS'),
#   ('during', 'IN'),
#   ('the', 'DT'),
#   ('walk', 'NN'),
#   (',', ','),
#   ('she', 'PRP'),
#   ('said', 'VBD'),
#   ('.', '.')],
#  [('Her', 'PRP$'),
#   ('youngest', 'JJS'),
#   (',', ','),
#   ('whom', 'WP'),
#   ('she', 'PRP'),
#   ('said', 'VBD'),
#   ('she', 'PRP'),
#   ('home', 'NN'),
#   ('schools', 'NNS'),
#   (',', ','),
#   ('refused', 'VBD'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('left', 'VBN'),
#   ('behind', 'IN'),
#   ('.', '.')],
#  [('When', 'WRB'),
#   ('Paulette', 'NNP'),
#   ('was', 'VBD'),
#   ('at', 'IN'),
#   ('her', 'PRP$'),
#   ('lowest', 'JJS'),
#   ('point', 'NN'),
#   ('fighting', 'VBG'),
#   ('cancer', 'NN'),
#   (',', ','),
#   ('she', 'PRP'),
#   ('said', 'VBD'),
#   (',', ','),
#   ('her', 'PRP$'),
#   ('daughter', 'NN'),
#   ('pushed', 'VBD'),
#   ('her', 'PRP'),
#   ('to', 'TO'),
#   ('battle', 'NN'),
#   ('on', 'IN'),
#   ('.', '.')],
#  [('``', '``'),
#   ('There', 'EX'),
#   ('were', 'VBD'),
#   ('days', 'NNS'),
#   ('I', 'PRP'),
#   ('wanted', 'VBD'),
#   ('to', 'TO'),
#   ('stop', 'VB'),
#   ('breathing', 'NN'),
#   ('.', '.')],
#  [('She', 'PRP'),
#   ("'d", 'MD'),
#   ('climb', 'VB'),
#   ('up', 'RP'),
#   ('into', 'IN'),
#   ('my', 'PRP$'),
#   ('bed', 'NN'),
#   ('and', 'CC'),
#   ('love', 'VB'),
#   ('all', 'DT'),
#   ('over', 'IN'),
#   ('me', 'PRP'),
#   ('.', '.')],
#  [('She', 'PRP'),
#   ("'d", 'MD'),
#   ('say', 'VB'),
#   (',', ','),
#   ("'Mama", 'FW'),
#   (',', ','),
#   ('promise', 'VB'),
#   ('me', 'PRP'),
#   ('you', 'PRP'),
#   ("'re", 'VBP'),
#   ('going', 'VBG'),
#   ('to', 'TO'),
#   ('beat', 'VB'),
#   ('cancer', 'NN'),
#   ('.', '.'),
#   ("'", "''")],
#  [('I', 'PRP'),
#   ('promised', 'VBD'),
#   ('her', 'PRP'),
#   ('and', 'CC'),
#   ('I', 'PRP'),
#   ('kept', 'VBD'),
#   ('it', 'PRP'),
#   ('.', '.')],
#  [('``', '``'),
#   ('The', 'DT'),
#   ('highway', 'NN'),
#   ('we', 'PRP'),
#   ('walked', 'VBD'),
#   ('along', 'RB'),
#   ('grew', 'VBD'),
#   ('busy', 'JJ'),
#   ('.', '.')],
#  [('When', 'WRB'),
#   ('Paulette', 'NNP'),
#   ("'s", 'POS'),
#   ('daughter', 'NN'),
# ...
#   ('and', 'CC'),
#   ('others', 'NNS'),
#   ('for', 'IN'),
#   ('pictures', 'NNS'),
#   ('.', '.')],
#  [('She', 'PRP'),
#   ('later', 'RB'),
#   ('posted', 'VBD'),
#   ('Facebook', 'NNP'),
#   ('pictures', 'NNS'),
#   ('with', 'IN'),
#   ('Rep.', 'NNP'),
#   ('Donald', 'NNP'),
#   ('M.', 'NNP'),
#   ('Payne', 'NNP'),
#   ('Jr.', 'NNP'),
#   (',', ','),
#   ('D-New', 'NNP'),
#   ('Jersey', 'NNP'),
#   (',', ','),
#   ('and', 'CC'),
#   ('Sen.', 'NNP'),
#   ('Roger', 'NNP'),
#   ('Wicker', 'NNP'),
#   (',', ','),
#   ('a', 'DT'),
#   ('Mississippi', 'NNP'),
#   ('Republican.Perhaps', 'NNP'),
#   ('she', 'PRP'),
#   ('grew', 'VBD'),
#   ('more', 'RBR'),
#   ('effective', 'JJ'),
#   ('as', 'IN'),
#   ('her', 'PRP$'),
#   ('visits', 'NNS'),
#   ('continued', 'VBN'),
#   ('.', '.')],
#  [('But', 'CC'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('meetings', 'NNS'),
#   ('I', 'PRP'),
#   ('attended', 'VBD'),
#   (',', ','),
#   ('Paulette', 'NNP'),
#   ('did', 'VBD'),
#   ("n't", 'RB'),
#   ('seem', 'VB'),
#   ('to', 'TO'),
#   ('understand', 'VB'),
#   ('that', 'IN'),
#   ('the', 'DT'),
#   ('people', 'NNS'),
#   ('she', 'PRP'),
#   ('was', 'VBD'),
#   ('meeting', 'VBG'),
#   ('with', 'IN'),
#   ('were', 'VBD'),
#   ('on', 'IN'),
#   ('her', 'PRP$'),
#   ('side', 'NN'),
#   ('--', ':'),
#   ('that', 'IN'),
#   ('they', 'PRP'),
#   (',', ','),
#   ('too', 'RB'),
#   (',', ','),
#   ('want', 'VBP'),
#   ('a', 'DT'),
#   ('cure', 'NN'),
#   ('for', 'IN'),
#   ('cancer', 'NN'),
#   ('and', 'CC'),
#   ('more', 'RBR'),
#   ('affordable', 'JJ'),
#   ('health', 'NN'),
#   ('care', 'NN'),
#   ('.', '.')],
#  [('Nor', 'CC'),
#   ('did', 'VBD'),
#   ('she', 'PRP'),
#   ('get', 'VB'),
#   ('how', 'WRB'),
#   ('the', 'DT'),
#   ('legislative', 'JJ'),
#   ('system', 'NN'),
#   ('works', 'VBZ'),
#   ('or', 'CC'),
#   ('which', 'WDT'),
#   ('laws', 'NNS'),
#   ('--', ':'),
#   ('including', 'VBG'),
#   ('the', 'DT'),
#   ('Affordable', 'NNP'),
#   ('Care', 'NNP'),
#   ('Act', 'NNP'),
#   ('--', ':'),
#   ('were', 'VBD'),
#   ('already', 'RB'),
#   ('in', 'IN'),
#   ('place.She', 'NN'),
#   ('complained', 'VBD'),
#   ('about', 'IN'),
#   ('insurance', 'NN'),
#   ('and', 'CC'),
#   ('pharmaceutical', 'JJ'),
#   ('companies', 'NNS'),
#   (',', ','),
#   ('talked', 'VBD'),
#   ('about', 'IN'),
#   ('being', 'VBG'),
#   ('a', 'DT'),
#   ('business', 'NN'),
#   ('owner', 'NN'),
#   ('for', 'IN'),
#   ('20', 'CD'),
#   ('years', 'NNS'),
#   ('who', 'WP'),
#   ('then', 'RB'),
#   ('became', 'VBD'),
#   ('homeless', 'NN'),
#   ('.', '.')],
#  [('She', 'PRP'),
#   ('said', 'VBD'),
#   ('she', 'PRP'),
#   ('made', 'VBD'),
#   ('$', '$'),
#   ('1', 'CD'),
#   ('too', 'RB'),
#   ('much', 'JJ'),
#   ('to', 'TO'),
#   ('qualify', 'VB'),
#   ('for', 'IN'),
#   ('food', 'NN'),
#   ('stamps', 'NNS'),
#   ('.', '.')],
#  [('She', 'PRP'),
#   ('said', 'VBD'),
#   ('she', 'PRP'),
#   ('had', 'VBD'),
#   ('to', 'TO'),
#   ('pay', 'VB'),
#   ('$', '$'),
#   ('5,000', 'CD'),
#   ('a', 'DT'),
#   ('month', 'NN'),
#   ('for', 'IN'),
#   ('her', 'PRP$'),
#   ('blood', 'NN'),
#   ('disorder', 'NN'),
#   ('treatments', 'NNS'),
#   ('.', '.')],
#  [('I', 'PRP'),
#   ('could', 'MD'),
#   ('only', 'RB'),
#   ('surmise', 'VB'),
#   ('that', 'IN'),
#   ('this', 'DT'),
#   ('was', 'VBD'),
#   ('in', 'IN'),
#   ('addition', 'NN'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('$', '$'),
#   ('2,500', 'CD'),
#   ('to', 'TO'),
#   ('$', '$'),
#   ('5,000', 'CD'),
#   ('a', 'DT'),
#   ('month', 'NN'),
#   ('she', 'PRP'),
#   ('often', 'RB'),
#   ('said', 'VBD'),
#   ('she', 'PRP'),
#   ('needed', 'VBD'),
#   ('to', 'TO'),
#   ('pay', 'VB'),
#   ('for', 'IN'),
#   ('her', 'PRP$'),
#   ('cancer', 'NN'),
#   ('treatments', 'NNS'),
#   ('.', '.')],
#  [('``', '``'),
#   ('You', 'PRP'),
#   ("'re", 'VBP'),
#   ('preaching', 'VBG'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('choir', 'NN'),
#   (',', ','),
#   ("''", "''"),
#   ('an', 'DT'),
#   ('aide', 'NN'),
#   ('said', 'VBD'),
#   ('.', '.')],
#  [('``', '``'),
#   ('This', 'DT'),
#   ('congressman', 'NN'),
#   ('shares', 'NNS'),
#   ('your', 'PRP$'),
#   ('concerns', 'NNS'),
#   ('.', '.')],
#  [('``', '``'),
#   ('He', 'PRP'),
#   ('explained', 'VBD'),
#   ('to', 'TO'),
#   ('her', 'PRP$'),
#   ('how', 'WRB'),
#   ('the', 'DT'),
#   ('system', 'NN'),
#   ('works', 'VBZ'),
#   (',', ','),
#   ('how', 'WRB'),
#   ('there', 'RB'),
#   ('needs', 'VBZ'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('a', 'DT'),
#   ('certain', 'JJ'),
#   ('number', 'NN'),
#   ('of', 'IN'),
#   ('votes', 'NNS'),
#   ('to', 'TO'),
#   ('pass', 'VB'),
#   ('bills', 'NNS'),
#   (',', ','),
#   ('how', 'WRB'),
#   ('she', 'PRP'),
#   ('needs', 'VBZ'),
#   ('to', 'TO'),
#   ('lobby', 'VB'),
#   ('in', 'IN'),
#   ('her', 'PRP$'),
#   ('own', 'JJ'),
#   ('district', 'NN'),
#   ('to', 'TO'),
#   ('effect', 'NN'),
#   ('change.Paulette', 'NN'),
#   ('listened', 'VBD'),
#   ('and', 'CC'),
#   ('demanded', 'VBD'),
#   (':', ':'),
#   ('``', '``'),
#   ('What', 'WP'),
#   ("'s", 'VBZ'),
#   ('more', 'JJR'),
#   ('important', 'JJ'),
#   ('than', 'IN'),
#   ('human', 'JJ'),
#   ('life', 'NN'),
#   ('?', '.')],
#  [('``', '``'),
#   ('This', 'DT'),
#   ('story', 'NN'),
#   ('was', 'VBD'),
#   ("n't", 'RB'),
#   ('just', 'RB'),
#   ('about', 'IN'),
#   ('Paulette', 'NNP'),
#   ('.', '.')],
#  [('It', 'PRP'),
#   ("'s", 'VBZ'),
#   ('about', 'IN'),
#   ('our', 'PRP$'),
#   ('need', 'NN'),
#   ('to', 'TO'),
#   ('find', 'VB'),
#   ('--', ':'),
#   ('and', 'CC'),
#   (',', ','),
#   ('for', 'IN'),
#   ('some', 'DT'),
#   ('of', 'IN'),
#   ('us', 'PRP'),
#   (',', ','),
#   ('become', 'VB'),
#   ('--', ':'),
#   ('heroes.There', 'EX'),
#   ("'s", 'VBZ'),
#   ('no', 'DT'),
#   ('way', 'NN'),
#   ('to', 'TO'),
#   ('measure', 'VB'),
#   ('how', 'WRB'),
#   ('much', 'JJ'),
#   ('of', 'IN'),
#   ('a', 'DT'),
#   ('difference', 'NN'),
#   ('Paulette', 'NNP'),
#   ('Leaphart', 'NNP'),
#   ('made', 'VBD'),
#   ('in', 'IN'),
#   ('shaping', 'VBG'),
#   ('the', 'DT'),
#   ('conversation', 'NN'),
#   ('about', 'IN'),
#   ('cancer', 'NN'),
#   ('in', 'IN'),
#   ('this', 'DT'),
#   ('country', 'NN'),
#   ('.', '.')],
#  [('She', 'PRP'),
#   ('touched', 'VBD'),
#   ('many', 'JJ'),
#   ('minds', 'NNS'),
#   ('and', 'CC'),
#   ('hearts', 'NNS'),
#   (',', ','),
#   ('but', 'CC'),
#   ('whether', 'IN'),
#   ('she', 'PRP'),
#   ('did', 'VBD'),
#   ('so', 'RB'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('most', 'RBS'),
#   ('honest', 'JJ'),
#   ('and', 'CC'),
#   ('transparent', 'JJ'),
#   ('way', 'NN'),
#   ('remains', 'VBZ'),
#   ('questionable.The', 'JJ'),
#   ('day', 'NN'),
#   ('after', 'IN'),
#   ('Christmas', 'NNP'),
#   (',', ','),
#   ('she', 'PRP'),
#   ('posted', 'VBD'),
#   ('a', 'DT'),
#   ('new', 'JJ'),
#   ('photo', 'NN'),
#   ('from', 'IN'),
#   ('a', 'DT'),
#   ('hospital', 'NN'),
#   ('bed', 'NN'),
#   ('.', '.')],
#  [('She', 'PRP'),
#   ('complained', 'VBD'),
#   ('of', 'IN'),
#   ('excruciating', 'VBG'),
#   ('pain', 'NN'),
#   ('and', 'CC'),
#   ('revealed', 'VBD'),
#   ('there', 'EX'),
#   ('was', 'VBD'),
#   ('a', 'DT'),
#   ('new', 'JJ'),
#   ('mass', 'NN'),
#   (',', ','),
#   ('this', 'DT'),
#   ('time', 'NN'),
#   ('next', 'JJ'),
#   ('to', 'TO'),
#   ('her', 'PRP$'),
#   ('right', 'JJ'),
#   ('ovary', 'NN'),
#   ('.', '.')],
#  [('My', 'PRP$'),
#   ('stomach', 'NN'),
#   ('dropped', 'VBD'),
#   ('for', 'IN'),
#   ('her', 'PRP'),
#   ('.', '.')],
#  [('She', 'PRP'),
#   ('asked', 'VBD'),
#   ('for', 'IN'),
#   ('prayers', 'NNS'),
#   (',', ','),
#   ('and', 'CC'),
#   ('they', 'PRP'),
#   ('came', 'VBD'),
#   ('in', 'IN'),
#   ('by', 'IN'),
#   ('the', 'DT'),
#   ('hundreds.Then', 'NN'),
#   (',', ','),
#   ('in', 'IN'),
#   ('less', 'JJR'),
#   ('than', 'IN'),
#   ('24', 'CD'),
#   ('hours', 'NNS'),
#   (',', ','),
#   ('her', 'PRP$'),
#   ('longtime', 'JJ'),
#   ('critic', 'JJ'),
#   ('Kimberly', 'NNP'),
#   ('McCarty', 'NNP'),
#   ('shared', 'VBD'),
#   ('an', 'DT'),
#   ('old', 'JJ'),
#   ('post', 'NN'),
#   ('that', 'WDT'),
#   ('questioned', 'VBD'),
#   ('whether', 'IN'),
#   ('Paulette', 'NNP'),
#   ('still', 'RB'),
#   ('had', 'VBD'),
#   ('her', 'PRP'),
#   ('ovaries', 'NNS'),
#   ('.', '.')],
#  [('In', 'IN'),
#   ('the', 'DT'),
#   ('post', 'NN'),
#   (',', ','),
#   ('one', 'CD'),
#   ('of', 'IN'),
#   ('Paulette', 'NNP'),
#   ("'s", 'POS'),
#   ('daughters', 'NNS'),
#   ('wrote', 'VBD'),
#   ('that', 'IN'),
#   ('her', 'PRP$'),
#   ('mother', 'NN'),
#   ("'s", 'POS'),
#   ('ovaries', 'NNS'),
#   ('were', 'VBD'),
#   ('being', 'VBG'),
#   ('removed', 'VBN'),
#   ('out', 'IN'),
#   ('of', 'IN'),
#   ('fear', 'NN'),
#   ('that', 'IN'),
#   ('the', 'DT'),
#   ('hormones', 'NNS'),
#   ('produced', 'VBN'),
#   ('by', 'IN'),
#   ('them', 'PRP'),
#   ('were', 'VBD'),
#   ('feeding', 'VBG'),
#   ('her', 'PRP$'),
#   ('breast', 'NN'),
#   ('cancer', 'NN'),
#   ('.', '.')],
#  [('And', 'CC'),
#   (',', ','),
#   ('once', 'RB'),
#   ('again', 'RB'),
#   (',', ','),
#   ('I', 'PRP'),
#   ('no', 'RB'),
#   ('longer', 'RBR'),
#   ('knew', 'VB'),
#   ('what', 'WP'),
#   ('to', 'TO'),
#   ('believe', 'VB'),
#   ('or', 'CC'),
#   ('feel.Then', 'VB'),
#   ('came', 'VBD'),
#   ('Facebook', 'NNP'),
#   ('photos', 'NNS'),
#   ('from', 'IN'),
#   ('Paulette', 'NNP'),
#   ('.', '.')],
#  [('In', 'IN'),
#   ('one', 'CD'),
#   ('she', 'PRP'),
#   ('was', 'VBD'),
#   ('getting', 'VBG'),
#   ('a', 'DT'),
#   ('vaginal', 'JJ'),
#   ('ultrasound', 'NN'),
#   ('.', '.')],
#  [('In', 'IN'),
#   ('another', 'DT'),
#   (',', ','),
#   ('she', 'PRP'),
#   ('was', 'VBD'),
#   ('flashing', 'VBG'),
#   ('the', 'DT'),
#   ('victory', 'NN'),
#   ('sign', 'NN'),
#   ('with', 'IN'),
#   ('her', 'PRP$'),
#   ('fingers', 'NNS'),
#   ('and', 'CC'),
#   ('smiling', 'VBG'),
#   ('as', 'IN'),
#   ('she', 'PRP'),
#   ('was', 'VBD'),
#   ('being', 'VBG'),
#   ('pushed', 'VBN'),
#   ('into', 'IN'),
#   ('an', 'DT'),
#   ('MRI', 'NNP'),
#   ('machine', 'NN'),
#   ('.', '.')],
#  [('She', 'PRP'),
#   ('posed', 'VBD'),
#   ('next', 'JJ'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('doctor', 'NN'),
#   ('who', 'WP'),
#   (',', ','),
#   ('she', 'PRP'),
#   ('said', 'VBD'),
#   (',', ','),
#   ('had', 'VBD'),
#   ('just', 'RB'),
#   ('removed', 'VBN'),
#   ('her', 'PRP$'),
#   ('ovaries', 'NNS'),
#   ('.', '.')],
#  [('There', 'EX'),
#   ('was', 'VBD'),
#   ('no', 'DT'),
#   ('cancer', 'NN'),
#   (',', ','),
#   ('she', 'PRP'),
#   ('later', 'RB'),
#   ('reported.In', 'VBD'),
#   ('the', 'DT'),
#   ('weeks', 'NNS'),
#   ('before', 'IN'),
#   ('publishing', 'VBG'),
#   ('this', 'DT'),
#   ('story', 'NN'),
#   (',', ','),
#   ('I', 'PRP'),
#   ('set', 'VBP'),
#   ('out', 'RP'),
#   ('to', 'TO'),
#   ('give', 'VB'),
#   ('Paulette', 'NNP'),
#   ('a', 'DT'),
#   ('chance', 'NN'),
#   ('to', 'TO'),
#   ('address', 'VB'),
#   ('questions', 'NNS'),
#   ('I', 'PRP'),
#   ('still', 'RB'),
#   ('had', 'VBD'),
#   ('and', 'CC'),
#   ('to', 'TO'),
#   ('respond', 'VB'),
#   ('to', 'TO'),
#   ('accusations', 'NNS'),
#   ('made', 'VBN'),
#   ('by', 'IN'),
#   ('others', 'NNS'),
#   ('.', '.')],
#  [('I', 'PRP'),
#   ('emailed', 'VBD'),
#   ('her', 'PRP'),
#   ('twice', 'RB'),
#   ('detailing', 'VBG'),
#   ('my', 'PRP$'),
#   ('reporting', 'NN'),
#   ('and', 'CC'),
#   ('asking', 'VBG'),
#   ('for', 'IN'),
#   ('answers', 'NNS'),
#   ('about', 'IN'),
#   ('everything', 'NN'),
#   ('from', 'IN'),
#   ('her', 'PRP$'),
#   ('career', 'NN'),
#   ('and', 'CC'),
#   ('court', 'NN'),
#   ('judgments', 'NNS'),
#   ('to', 'TO'),
#   ('her', 'PRP$'),
#   ('cancer', 'NN'),
#   ('and', 'CC'),
#   ('treatment', 'NN'),
#   ('.', '.')],
#  [('When', 'WRB'),
#   ('I', 'PRP'),
#   ('got', 'VBD'),
#   ('no', 'DT'),
#   ('reply', 'NN'),
#   (',', ','),
#   ('I', 'PRP'),
#   ('texted', 'VBD'),
#   ('her', 'PRP'),
#   ('and', 'CC'),
#   ('even', 'RB'),
#   ('had', 'VBD'),
#   ('my', 'PRP$'),
#   ('editor', 'NN'),
#   ('send', 'VB'),
#   ('her', 'PRP'),
#   ('a', 'DT'),
#   ('Facebook', 'NNP'),
#   ('message', 'NN'),
#   ('.', '.')],
#  [('Then', 'RB'), ('I', 'PRP'), ('called', 'VBD'), ('her', 'PRP'), ('.', '.')],
#  [('She', 'PRP'),
#   ('indicated', 'VBD'),
#   ('she', 'PRP'),
#   ('had', 'VBD'),
#   ('seen', 'VBN'),
#   ('my', 'PRP$'),
#   ('questions', 'NNS'),
#   ('and', 'CC'),
#   ('told', 'VBD'),
#   ('me', 'PRP'),
#   ('she', 'PRP'),
#   ('did', 'VBD'),
#   ("n't", 'RB'),
#   ('want', 'VB'),
#   ('to', 'TO'),
#   ('talk', 'VB'),
#   ('to', 'TO'),
#   ('me.Soon', 'NN'),
#   ('after', 'IN'),
#   ('my', 'PRP$'),
#   ('first', 'JJ'),
#   ('email', 'NN'),
#   (',', ','),
#   ('Paulette', 'NNP'),
#   ('thanked', 'VBD'),
#   ('Jesus', 'NNP'),
#   ('on', 'IN'),
#   ('Facebook', 'NNP'),
#   ('for', 'IN'),
#   ('her', 'PRP$'),
#   ('``', '``'),
#   ('brand', 'NN'),
#   ('spanking', 'VBG'),
#   ('new', 'JJ'),
#   ('house', 'NN'),
#   ("''", "''"),
#   ('and', 'CC'),
#   ('shared', 'VBD'),
#   ('a', 'DT'),
#   ('photograph', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('home', 'NN'),
#   ('.', '.')],
#  [('``', '``'),
#   ('I', 'PRP'),
#   ('obeyed', 'VBD'),
#   ('him', 'PRP'),
#   (',', ','),
#   ("''", "''"),
#   ('she', 'PRP'),
#   ('said', 'VBD'),
#   ('of', 'IN'),
#   ('God', 'NNP'),
#   (',', ','),
#   ('``', '``'),
#   ('even', 'RB'),
#   ('when', 'WRB'),
#   ('the', 'DT'),
#   ('devil', 'NN'),
#   ('was', 'VBD'),
#   ('riding', 'VBG'),
#   ('my', 'PRP$'),
#   ('back', 'NN'),
#   ('.', '.')],
#  [('``', '``'),
#   ('Days', 'NNS'),
#   ('before', 'IN'),
#   ('we', 'PRP'),
#   ('published', 'VBD'),
#   ('this', 'DT'),
#   ('story', 'NN'),
#   (',', ','),
#   ('Paulette', 'NNP'),
#   ('took', 'VBD'),
#   ('to', 'TO'),
#   ('Facebook', 'NNP'),
#   ('Live', 'NNP'),
#   ('and', 'CC'),
#   ('said', 'VBD'),
#   ('that', 'IN'),
#   ('about', 'IN'),
#   ('25', 'CD'),
#   ('years', 'NNS'),
#   ('ago', 'RB'),
#   (',', ','),
#   ('after', 'IN'),
#   ('multiple', 'JJ'),
#   ('suicide', 'NN'),
#   ('attempts', 'NNS'),
#   ('and', 'CC'),
#   ('a', 'DT'),
#   ('nervous', 'JJ'),
#   ('breakdown', 'NN'),
#   (',', ','),
#   ('she', 'PRP'),
#   ('was', 'VBD'),
#   ('diagnosed', 'VBN'),
#   ('with', 'IN'),
#   ('dissociative', 'JJ'),
#   ('identity', 'NN'),
#   ('disorder', 'NN'),
#   (',', ','),
#   ('formerly', 'RB'),
#   ('called', 'VBD'),
#   ('multiple', 'JJ'),
#   ('personality', 'NN'),
#   ('disorder', 'NN'),
#   ('.', '.')],
#  [('She', 'PRP'),
#   ('said', 'VBD'),
#   ('10', 'CD'),
#   ('years', 'NNS'),
#   ('of', 'IN'),
#   ('therapy', 'NN'),
#   ('helped', 'VBD'),
#   ('her', 'PRP$'),
#   ('integrate', 'NN'),
#   ('more', 'JJR'),
#   ('than', 'IN'),
#   ('20', 'CD'),
#   ('personalities', 'NNS'),
#   ('.', '.')],
#  [('She', 'PRP'),
#   ('said', 'VBD'),
#   ('she', 'PRP'),
#   ('was', 'VBD'),
#   ('going', 'VBG'),
#   ('public', 'JJ'),
#   ('with', 'IN'),
#   ('this', 'DT'),
#   ('after', 'IN'),
#   ('reading', 'VBG'),
#   ('about', 'IN'),
#   ('the', 'DT'),
#   ('movie', 'NN'),
#   ('``', '``'),
#   ('Split', 'NNP'),
#   (',', ','),
#   ("''", "''"),
#   ('by', 'IN'),
#   ('M.', 'NNP'),
#   ('Night', 'NNP'),
#   ('Shyamalan', 'NNP'),
#   ('.', '.')],
#  [('Once', 'RB'),
#   ('more', 'JJR'),
#   (',', ','),
#   ('I', 'PRP'),
#   ('felt', 'VBD'),
#   ('for', 'IN'),
#   ('her', 'PRP$'),
#   ('--', ':'),
#   ('and', 'CC'),
#   ('wished', 'VBD'),
#   ('I', 'PRP'),
#   ('could', 'MD'),
#   ('know', 'VB'),
#   ('what', 'WP'),
#   ('to', 'TO'),
#   ('believe.Paulette', 'VB'),
#   ('likes', 'NNS'),
#   ('to', 'TO'),
#   ('say', 'VB'),
#   ('that', 'IN'),
#   ('when', 'WRB'),
#   ('life', 'NN'),
#   ('gave', 'VBD'),
#   ('her', 'PRP'),
#   ('lemons', 'NNS'),
#   (',', ','),
#   ('she', 'PRP'),
#   ('made', 'VBD'),
#   ('lemonade', 'NN'),
#   ('.', '.')],
#  [('She', 'PRP'),
#   ('adopted', 'VBD'),
#   ('yellow', 'JJ'),
#   ('as', 'IN'),
#   ('the', 'DT'),
#   ('color', 'NN'),
#   ('of', 'IN'),
#   ('her', 'PRP$'),
#   ('campaign', 'NN'),
#   ('and', 'CC'),
#   ('often', 'RB'),
#   ('says', 'VBZ'),
#   ('``', '``'),
#   ('yellow', 'JJ'),
#   ('is', 'VBZ'),
#   ('the', 'DT'),
#   ('new', 'JJ'),
#   ('pink', 'NN'),
#   ('.', '.'),
#   ("''", "''")],
#  [('She', 'PRP'),
#   ('once', 'RB'),
#   ('mused', 'VBD'),
#   ('out', 'RP'),
#   ('loud', 'JJ'),
#   ('as', 'IN'),
#   ('we', 'PRP'),
#   ('walked', 'VBD'),
#   ('in', 'IN'),
#   ('North', 'NNP'),
#   ('Carolina', 'NNP'),
#   ('whether', 'IN'),
#   ('the', 'DT'),
#   ('Susan', 'NNP'),
#   ('G.', 'NNP'),
#   ('Komen', 'NNP'),
#   ('Foundation', 'NNP'),
#   (',', ','),
#   ('the', 'DT'),
#   ('embodiment', 'NN'),
#   ('of', 'IN'),
#   ('all', 'DT'),
#   ('things', 'NNS'),
#   ('pink', 'VBP'),
#   ('and', 'CC'),
#   ('cancer', 'NN'),
#   (',', ','),
#   ('would', 'MD'),
#   ('put', 'VB'),
#   ('out', 'RP'),
#   ('a', 'DT'),
#   ('hit', 'NN'),
#   ('on', 'IN'),
#   ('her', 'PRP$'),
#   ('for', 'IN'),
#   ('stealing', 'VBG'),
#   ('attention', 'NN'),
#   ('from', 'IN'),
#   ('its', 'PRP$'),
#   ('organization.I', 'NN'),
#   ('do', 'VBP'),
#   ("n't", 'RB'),
#   ('think', 'VB'),
#   ('I', 'PRP'),
#   ("'ll", 'MD'),
#   ('ever', 'RB'),
#   ('know', 'VB'),
#   ('the', 'DT'),
#   ('full', 'JJ'),
#   ('truth', 'NN'),
#   ('about', 'IN'),
#   ('Paulette', 'NNP'),
#   ('.', '.')],
#  [('But', 'CC'),
#   ('the', 'DT'),
#   ('color', 'NN'),
#   ('that', 'WDT'),
#   ('comes', 'VBZ'),
#   ('to', 'TO'),
#   ('mind', 'VB'),
#   ('when', 'WRB'),
#   ('I', 'PRP'),
#   ('think', 'VBP'),
#   ('of', 'IN'),
#   ('her', 'PRP$'),
#   ('is', 'VBZ'),
#   ('neither', 'DT'),
#   ('yellow', 'JJ'),
#   ('nor', 'CC'),
#   ('pink', 'NN'),
#   ('.', '.')],
#  [('It', 'PRP'),
#   ("'s", 'VBZ'),
#   ('the', 'DT'),
#   ('murkiest', 'NN'),
#   ('of', 'IN'),
#   ('grays', 'NNS'),
#   ('.', '.')]]

# %%
nltk.download('tagsets')
nltk.help.upenn_tagset()
# Out:
# [nltk_data] Downloading package tagsets to /home/harish/nltk_data...
# [nltk_data]   Package tagsets is already up-to-date!
# $: dollar
#     $ -$ --$ A$ C$ HK$ M$ NZ$ S$ U.S.$ US$
# '': closing quotation mark
#     ' ''
# (: opening parenthesis
#     ( [ {
# ): closing parenthesis
#     ) ] }
# ,: comma
#     ,
# --: dash
#     --
# .: sentence terminator
#     . ! ?
# :: colon or ellipsis
#     : ; ...
# CC: conjunction, coordinating
#     & 'n and both but either et for less minus neither nor or plus so
#     therefore times v. versus vs. whether yet
# CD: numeral, cardinal
#     mid-1890 nine-thirty forty-two one-tenth ten million 0.5 one forty-
#     seven 1987 twenty '79 zero two 78-degrees eighty-four IX '60s .025
#     fifteen 271,124 dozen quintillion DM2,000 ...
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those
# EX: existential there
#     there
# FW: foreign word
#     gemeinschaft hund ich jeux habeas Haementeria Herr K'ang-si vous
#     lutihaw alai je jour objets salutaris fille quibusdam pas trop Monte
#     terram fiche oui corporis ...
# IN: preposition or conjunction, subordinating
#     astride among uppon whether out inside pro despite on by throughout
#     below within for towards near behind atop around if like until below
#     next into if beside ...
# JJ: adjective or numeral, ordinal
#     third ill-mannered pre-war regrettable oiled calamitous first separable
#     ectoplasmic battery-powered participatory fourth still-to-be-named
#     multilingual multi-disciplinary ...
# JJR: adjective, comparative
#     bleaker braver breezier briefer brighter brisker broader bumper busier
#     calmer cheaper choosier cleaner clearer closer colder commoner costlier
#     cozier creamier crunchier cuter ...
# JJS: adjective, superlative
#     calmest cheapest choicest classiest cleanest clearest closest commonest
#     corniest costliest crassest creepiest crudest cutest darkest deadliest
#     dearest deepest densest dinkiest ...
# LS: list item marker
#     A A. B B. C C. D E F First G H I J K One SP-44001 SP-44002 SP-44005
#     SP-44007 Second Third Three Two * a b c d first five four one six three
#     two
# MD: modal auxiliary
#     can cannot could couldn't dare may might must need ought shall should
#     shouldn't will would
# NN: noun, common, singular or mass
#     common-carrier cabbage knuckle-duster Casino afghan shed thermostat
#     investment slide humour falloff slick wind hyena override subhumanity
#     machinist ...
# NNP: noun, proper, singular
#     Motown Venneboerger Czestochwa Ranzer Conchita Trumplane Christos
#     Oceanside Escobar Kreisler Sawyer Cougar Yvette Ervin ODI Darryl CTCA
#     Shannon A.K.C. Meltex Liverpool ...
# NNPS: noun, proper, plural
#     Americans Americas Amharas Amityvilles Amusements Anarcho-Syndicalists
#     Andalusians Andes Andruses Angels Animals Anthony Antilles Antiques
#     Apache Apaches Apocrypha ...
# NNS: noun, common, plural
#     undergraduates scotches bric-a-brac products bodyguards facets coasts
#     divestitures storehouses designs clubs fragrances averages
#     subjectivists apprehensions muses factory-jobs ...
# PDT: pre-determiner
#     all both half many quite such sure this
# POS: genitive marker
#     ' 's
# PRP: pronoun, personal
#     hers herself him himself hisself it itself me myself one oneself ours
#     ourselves ownself self she thee theirs them themselves they thou thy us
# PRP$: pronoun, possessive
#     her his mine my our ours their thy your
# RB: adverb
#     occasionally unabatingly maddeningly adventurously professedly
#     stirringly prominently technologically magisterially predominately
#     swiftly fiscally pitilessly ...
# RBR: adverb, comparative
#     further gloomier grander graver greater grimmer harder harsher
#     healthier heavier higher however larger later leaner lengthier less-
#     perfectly lesser lonelier longer louder lower more ...
# RBS: adverb, superlative
#     best biggest bluntest earliest farthest first furthest hardest
#     heartiest highest largest least less most nearest second tightest worst
# RP: particle
#     aboard about across along apart around aside at away back before behind
#     by crop down ever fast for forth from go high i.e. in into just later
#     low more off on open out over per pie raising start teeth that through
#     under unto up up-pp upon whole with you
# SYM: symbol
#     % & ' '' ''. ) ). * + ,. < = > @ A[fj] U.S U.S.S.R * ** ***
# TO: "to" as preposition or infinitive marker
#     to
# UH: interjection
#     Goodbye Goody Gosh Wow Jeepers Jee-sus Hubba Hey Kee-reist Oops amen
#     huh howdy uh dammit whammo shucks heck anyways whodunnit honey golly
#     man baby diddle hush sonuvabitch ...
# VB: verb, base form
#     ask assemble assess assign assume atone attention avoid bake balkanize
#     bank begin behold believe bend benefit bevel beware bless boil bomb
#     boost brace break bring broil brush build ...
# VBD: verb, past tense
#     dipped pleaded swiped regummed soaked tidied convened halted registered
#     cushioned exacted snubbed strode aimed adopted belied figgered
#     speculated wore appreciated contemplated ...
# VBG: verb, present participle or gerund
#     telegraphing stirring focusing angering judging stalling lactating
#     hankerin' alleging veering capping approaching traveling besieging
#     encrypting interrupting erasing wincing ...
# VBN: verb, past participle
#     multihulled dilapidated aerosolized chaired languished panelized used
#     experimented flourished imitated reunifed factored condensed sheared
#     unsettled primed dubbed desired ...
# VBP: verb, present tense, not 3rd person singular
#     predominate wrap resort sue twist spill cure lengthen brush terminate
#     appear tend stray glisten obtain comprise detest tease attract
#     emphasize mold postpone sever return wag ...
# VBZ: verb, present tense, 3rd person singular
#     bases reconstructs marks mixes displeases seals carps weaves snatches
#     slumps stretches authorizes smolders pictures emerges stockpiles
#     seduces fizzes uses bolsters slaps speaks pleads ...
# WDT: WH-determiner
#     that what whatever which whichever
# WP: WH-pronoun
#     that what whatever whatsoever which who whom whosoever
# WP$: WH-pronoun, possessive
#     whose
# WRB: Wh-adverb
#     how however whence whenever where whereby whereever wherein whereof why
# ``: opening quotation mark
#     ` ``

# %%
gpe = []
# locations = [] # opens an empty list for locations
gpe =[] #opens an empty list for geopolitical entities
persons = [] #opens an empty list for persons
organizations = [] #opens an empty list for organizations


for i in tagged_sentences: # for each part of speech tagged sentence in a tagged_sentences list, extract named entities based on the chunking
    chunked_sentence = nltk.ne_chunk(i, binary=False) # predict which noun phrases in the text are named entities. If binary is set to True, ask the model to predict whether something is a named entity or not. If set to False, the model predicts the type of named entity.   
#     print(chunked_sentence)
#     break
    gpe.extend(extract_entity_names(chunked_sentence, 'GPE'))#extract geopolitical entities from the text
    #locations.extend(extract_entity_names(chunked_sentence, 'LOCATION')) # extract loctions from the text
    persons.extend(extract_entity_names(chunked_sentence, 'PERSON')) #extract persons from the text
    organizations.extend(extract_entity_names(chunked_sentence, 'ORGANIZATION')) #extract organizations from the text

# %%
set(organizations)
# Out:
# {'Affordable Care',
#  'American Cancer Society',
#  'BRCA',
#  'BeyoncéIt',
#  'CBS',
#  'CNN',
#  'Cadillac',
#  'Capitol',
#  'Catholic',
#  'Centers',
#  'Century Cures Act',
#  'Congress',
#  'Cook Out',
#  'Cummings',
#  'Democratic',
#  'ESPN',
#  'Facebook',
#  'Finney',
#  'Forrest Gump',
#  'Fort Worth',
#  'GoFundMe',
#  'GodI',
#  'ID',
#  'IRS',
#  'Labor',
#  'LeaphartApropos',
#  'LeaphartIt',
#  'MD Anderson',
#  'MRI',
#  'MacKenzie',
#  'McCarty',
#  'McDonald',
#  'Mercedes',
#  'Michigan',
#  'Mississippi',
#  'PauletteIt',
#  'PauletteOne',
#  'Santa Claus',
#  'Susan',
#  'THE',
#  'US',
#  'United State',
#  'Upworthy',
#  'backI',
#  'crowdShe',
#  'defensePorsha Cummings',
#  'directionPart',
#  'espnW Pegasus Award',
#  'espnW Women',
#  'messageOne',
#  'questionsThe',
#  'recordsPaulette',
#  'woesAs'}

# %%
# why McDonald?
for n in kwicdict['McDonald']: # nicely formatted output for the word we are interested in determining the context for
    outstring = ' '.join(n[:3]).rjust(30) #output as a string and right justify first three words in the sliding window
    outstring += str(n[3]).center(len(n[3])+6) # output as a string and center fourth word in the sliding window
    outstring += ' '.join(n[4:]) # output as a string last three words in the sliding window of 7 consecutive words in the text
    print(outstring)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-202-d3be1c2d6f82> in <module>()
#       1 # why McDonald?
# ----> 2 for n in kwicdict['McDonald']: # nicely formatted output for the word we are interested in determining the context for
#       3     outstring = ' '.join(n[:3]).rjust(30) #output as a string and right justify first three words in the sliding window
#       4     outstring += str(n[3]).center(len(n[3])+6) # output as a string and center fourth word in the sliding window
#       5     outstring += ' '.join(n[4:]) # output as a string last three words in the sliding window of 7 consecutive words in the text
#
# KeyError: 'McDonald'

# %%
set(persons)
# Out:
# {'Adams',
#  'Always Beautiful',
#  'Angelina Jolie',
#  'Annette',
#  'Ashia',
#  'Ashia McDonald',
#  'Auntie Paulette',
#  'Barack Obama',
#  'Barbara',
#  'Barbara Smith',
#  'Beyoncé',
#  'Biloxi Beach',
#  'Blue Ivy',
#  'Brenda McDonald',
#  'Candy',
#  'Candy McDonald',
#  'Carmen Lawrence',
#  'Chantay Savage',
#  'Charlotte',
#  'Child',
#  'Christmas',
#  'Craig Leaphart',
#  'Cummings',
#  'David McKenzie',
#  'Destiny',
#  'Director',
#  'Disease Control',
#  'Donald M. Payne Jr.',
#  'Dusk',
#  'Emily',
#  'Emily MacKenzie',
#  'Facebook',
#  'Facebook Live',
#  'Fantasia',
#  'Filmmaker',
#  'Finney',
#  'Fulston',
#  'Girls Trip',
#  'God',
#  'Harry',
#  'Harry Connick Jr.',
#  'Hill',
#  'Jada Pinkett Smith',
#  'Jamaica',
#  'Jesus',
#  'Jesus Storybook Bible',
#  'John Conyers',
#  'Johnson',
#  'Katrina Adams',
#  'Kenya',
#  'Kimberly McCarty',
#  'Labor',
#  'Lawrence',
#  'Leaphart',
#  'Maclin',
#  'Marriott',
#  'Marwin Jones',
#  'McCarty',
#  'Melanye Maclin',
#  'Memorial',
#  'Michelle Obama',
#  'Michigan',
#  'Mom',
#  'Monique',
#  'Monique McDonald',
#  'Nikky',
#  'Nikky Finney',
#  'Oprah Winfrey',
#  'Paulette',
#  'Paulette Leaphart',
#  'Paulette.Johnson',
#  'Queen Latifah',
#  'Roger Wicker',
#  'Santa',
#  'Scar Story',
#  'Scott',
#  'Scott Bakula',
#  'Shameka Fulston',
#  'Sidney Williams',
#  'Smith',
#  'Split',
#  'Will Smith',
#  'Williams',
#  'Women Summit',
#  'Zane'}

# %%
from collections import Counter,OrderedDict

dict_persons = Counter(persons)
dict_persons.most_common()

# %% [markdown]
# ### Extracting Noun phrases:

# %%
nounphrases = []
grammar = "NP: {<DT>?<JJ>*<NN>}" #running regular expressions on part of speech to obtain noun phrase constituents from the text
for sent in tagged_sentences:
    cp = nltk.RegexpParser(grammar)
    result = cp.parse(sent)
    for sent in result.subtrees():
            if sent.label() == "NP":
                nounphrases.append(str(sent.leaves()))
for i in nounphrases:
    print (i)

# %% [markdown]
# # Sentiment_Analysis

# %%
nltk.download("vader_lexicon")
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/harish/nltk_data...
# True
